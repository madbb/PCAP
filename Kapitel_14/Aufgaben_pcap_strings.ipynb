# %% [markdown]
# # Aufgaben: Pcap strings

# %% [markdown]
# ## PCAP-Fragen: Strings

# %% [markdown]
# Frage 1: <br>
# Given the code below, what is the output?
# ```python
# string = "Python is great"
# print(bool(string[-1:-3:-2]))
# ```
#
# - False
# - []
# - t
# - True

# %% [markdown]
# Frage 2: <br>
# What will happen if we try to execute the following code?
# ```python
# word = "Python"
# word[1] = "i"
# print(word)
# ```
#
# - Pithon
# - Pythoi
# - TypeError 'str' object does not support item assignment
# - SyntaxError

# %% [markdown]
# Frage 3: <br>
# What is the ouput of the code?
# ```python
# text = "PCAP"
# print(ord(text[2:3:2]))
# ```
#
# - []
# - A
# - 65
# - 97

# %%
text = "PCAP"
print(ord(text[2:3:2]))
# Out:
# 65

# %% [markdown]
# Frage 4: <br>
# Given the following code, what is the output?
# ```python
# phrase = "hello python world"
# print(phrase.capitalize().replace("world", "WORLD").swapcase().split()[1][3:5] == "ho".upper())
# ```
#
# - False
# - TypeError
# - hO
# - True

# %%
phrase = "hello python world"
print(phrase.capitalize().replace("world", "WORLD").swapcase().split()[1][3:5] == "ho".upper())
# Out:
# True

# %% [markdown]
# Frage 5: <br>
# What will be the output of the following code?
# ```python
# text = "Python uses strings!"
# print(text.split(" ")[1].title().replace("s", "S"))
# ```
#
# - uSeS
# - Python Uses Strings!
# - StringS
# - USeS

# %% [markdown]
# Frage 6: <br>
# What will be the output of the following code?
# ```python
# x = '\''
# print(len(x))
# ```
#
# - SyntaxError
# - 2
# - 0
# - 1

# %% [markdown]
# Frage 7: <br>
# What will be the output of the following code?
# ```python
# print("xyz" + "abc" * 3)
# ```
#
# - abcxyzxyzxyz
# - TypeError
# - abcabcabcxyz
# - xyzabcabcabc

# %%
print("xyz" + "abc" * 3)
# Out:
# xyzabcabcabc

# %%
text = "Python uses strings!"
print(text.split(" ")[1].title().replace("s", "S"))
# Out:
# USeS

# %% [markdown]
# Frage 8: <br>
# What is the output of this code?
# ```python
# text = "Testing Strings"
# print(text.index("t", 4))
# ```
#
# - 9
# - 3
# - 4
# - IndexError

# %%
text = "Testing Strings"
print(text.index("t", 4))
# Out:
# 9

# %% [markdown]
# Frage 9: <br>
# What is the expected outcome for this code snippet?
# ```python
# word = "Algorithmus"
# print(word.find("g") + word.find("t"))
# ```
#
# - gt
# - 7
# - 8
# - 5

# %% [markdown]
# Frage 10: <br>
# What will be the output of the following code?
# ```python
# s = "pcap-exam"
# print(s.find("-") + s.rfind("a"))
# ```
# - 11
# - 9
# - 10
# - TypeError

# %% [markdown]
# Frage 11: <br>
# Whats the output of following code?
# ```python
# sentence = "web development with python"
# print(sentence.title().replace("e", "E", sentence.find("y")))
# ```
#
# - Web Development With Python
# - 22
# - WEb DEvElopmEnt With Python
# - WEb DEvElopmEnt with Python

# %% [markdown]
# Frage 12: <br>
# What will be the output of the following code?
# ```python
# print("-".join(["python", "3"]))
# ```
#
# - python-3
# - ["python", "3"]
# - python - 3
# - TypeError

# %% [markdown]
# Frage 13: <br>
# What will be the output of the following code?
# ```python
# text = "abracadabra"
# print(text.count("a", 0, 5))
# ```
#
# - 5
# - 3
# - 2
# - 4

# %% [markdown]
# Frage 14: <br>
# What will be the output of the following code?
# ```python
# print(ord('c') - ord('a'))
# ```
# - 3
# - 0
# - 2
# - 4

# %% [markdown]
# Frage 15: <br>
# What will be the output of the following code?
# ```python
# print(bool("") + bool("PCAP"))
# ```
# - 2
# - 1
# - 0
# - TypeError

# %% [markdown]
# Frage 16: <br>
# What will be the output of the following code?
# ```python
# print(str(True) + str(False))
# ```
# - TrueFalse
# - False
# - True
# - SyntaxError

# %%
print(str(True) + str(False))
# Out:
# TrueFalse

# %% [markdown]
# Frage 17: <br>
# What will be the output of the following code?
# ```python
# x = "42"
# print(x.isdigit() and not x.isalpha())
# ```
# - False
# - True
# - 42
# - None

# %%
x = "42"
print(x.isdigit() and not x.isalpha())
# Out:
# True

# %% [markdown]
# Frage 18: <br>
# What will be the output of the following code?
# ```python
# word = "  stripped  "
# print(word.strip().center(12, "*"))
# ```
# - stripped
# - \*stripped*
# - \*\*\*\*\*\*stripped******
# - \*\*stripped**

# %% [markdown]
# Frage 19: <br>
# What will be the output of the following code?
# ```python
# name = "Guido"
# print(f"{name[0]}{len(name)}{name[-1]}")
# ```
# - G4o
# - G5d
# - G5o
# - G6o

# %% [markdown]
# Frage 20: <br>
# What will be the output of the following code?
# ```python
# text = "spaces   everywhere"
# print(" ".join(text.split()).upper())
# ```
# - SPACES  &nbsp;&nbsp;&nbsp;&nbsp;  EVERYWHERE
# - spaces EVERYWHERE
# - SPACES everywhere
# - SPACES EVERYWHERE

# %% [markdown]
# ### Lösungen

# %% [markdown]
# Antwort 1:
# - True

# %% [markdown]
# Antwort 2:
# - TypeError: 'str' object does not support item assignment

# %% [markdown]
# Antwort 3:
# - 65

# %% [markdown]
# Antwort 4:
# - True

# %% [markdown]
# Antwort 5:
# - USeS

# %% [markdown]
# Antwort 6:
# - 1

# %% [markdown]
# Antwort 7:
# - abcabcabcxyz

# %% [markdown]
# Antwort 8:
# - 9

# %% [markdown]
# Antwort 9:
# - 8

# %% [markdown]
# Antwort 10:
# - 11

# %% [markdown]
# Antwort 11:
# - WEb DEvElopmEnt With Python

# %% [markdown]
# Antwort 12:
# - python-3

# %% [markdown]
# Antwort 13:
# - 2

# %% [markdown]
# Antwort 14:
# - 2

# %% [markdown]
# Antwort 15:
# - 1

# %% [markdown]
# Antwort 16:
# - TrueFalse

# %% [markdown]
# Antwort 17:
# - True

# %% [markdown]
# Antwort 18:
# - \*\*stripped**

# %% [markdown]
# Antwort 19:
# - G5o

# %% [markdown]
# Antwort 20:
# - SPACES EVERYWHERE
