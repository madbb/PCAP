# %% [markdown]
# # PCAP Übungsklausur 2 – Lösungsschlüssel
#
# **Alle 40 Antworten verifiziert.**

# %% [markdown]
# ## Sektion 1: Module und Pakete
#
# 1. B
# 2. C
# 3. A
# 4. C
# 5. B
# 6. C

# %% [markdown]
# ## Sektion 2: Exceptions
#
# 7. B
# 8. A
# 9. C
# 10. B
# 11. C
# 12. D

# %% [markdown]
# ## Sektion 3: Strings
#
# 13. B
# 14. A
# 15. C
# 16. B
# 17. C
# 18. A
# 19. B
# 20. B

# %% [markdown]
# ## Sektion 4: OOP
#
# 21. C
# 22. B
# 23. D
# 24. A
# 25. C
# 26. B
# 27. A
# 28. C
# 29. D
# 30. C
# 31. C
# 32. B
# 33. A
# 34. C

# %% [markdown]
# ## Sektion 5: Closures, List Comprehensions, Lambda
#
# 35. B
# 36. C
# 37. B
# 38. A
# 39. C
# 40. B
