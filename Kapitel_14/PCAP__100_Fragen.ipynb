# %% [markdown]
# # PCAP-31-03  Fragenpool – 100 Fragen
#
# | Sektion | Thema | Fragen |
# |---|---|---|
# | 1 | Module und Pakete | 1–20 |
# | 2 | Exceptions | 21–40 |
# | 3 | Strings | 41–60 |
# | 4 | OOP | 61–80 |
# | 5 | List Comprehensions / Lambda / Closures / I/O | 81–100 |

# %% [markdown]
# ---
# ## Sektion 1: Module und Pakete

# %% [markdown]
# **Frage 1**
#
# Was gibt dieser Code aus?
# ```python
# import math as m
# print(m.floor(3.9))
# ```
# A) `3.9`
# B) `3`
# C) `4`
# D) `NameError`

# %% [markdown]
# **Frage 2**
#
# Was gibt dieser Code aus?
# ```python
# from math import sqrt, floor
# print(floor(sqrt(16)))
# ```
# A) `2`
# B) `2.0`
# C) `4`
# D) `4.0`

# %% [markdown]
# **Frage 3**
#
# Was gibt dieser Code aus?
# ```python
# from math import *
# print(ceil(2.1))
# ```
# A) `3`
# B) `2`
# C) `2.1`
# D) `NameError`

# %% [markdown]
# **Frage 4**
#
# Was gibt dieser Code aus?
# ```python
# import math
# x = math.floor
# print(x(7.9))
# ```
# A) `7.9`
# B) `8`
# C) `TypeError`
# D) `7`

# %% [markdown]
# **Frage 5**
#
# Was gibt dieser Code aus?
# ```python
# import sys
# print(type(sys.path[0]))
# ```
# A) `<class 'list'>`
# B) `<class 'str'>`
# C) `<class 'tuple'>`
# D) `<class 'bytes'>`

# %% [markdown]
# **Frage 6**
#
# Was gibt dieser Code aus?
# ```python
# import math
# result = dir(math)
# print(isinstance(result, list), 'sqrt' in result)
# ```
# A) `True True`
# B) `True False`
# C) `False True`
# D) `False False`

# %% [markdown]
# **Frage 7**
#
# Was gibt dieser Code aus?
# ```python
# import math
# print('__name__' in dir(math))
# ```
# A) `False`
# B) `None`
# C) `True`
# D) `AttributeError`

# %% [markdown]
# **Frage 8**
#
# Was gibt dieser Code aus?
# ```python
# from math import floor as f
# print(f(3.9))
# ```
# A) `NameError`
# B) `3.9`
# C) `4`
# D) `3`

# %% [markdown]
# **Frage 9**
#
# Was gibt dieser Code aus?
# ```python
# import math
# print(math.floor(-0.1))
# ```
# A) `0`
# B) `-1`
# C) `0.0`
# D) `-0`

# %% [markdown]
# **Frage 10**
#
# Was gibt dieser Code aus?
# ```python
# import math
# print(math.ceil(-2.9))
# ```
# A) `-2`
# B) `-3`
# C) `-2.9`
# D) `3`

# %% [markdown]
# **Frage 11**
#
# Was gibt dieser Code aus?
# ```python
# import math
# print(math.trunc(3.9), math.trunc(-3.9))
# ```
# A) `4 -4`
# B) `3 -4`
# C) `3 -3`
# D) `4 -3`

# %% [markdown]
# **Frage 12**
#
# Was gibt dieser Code aus?
# ```python
# import math
# print(math.factorial(0))
# ```
# A) `0`
# B) `None`
# C) `ValueError`
# D) `1`

# %% [markdown]
# **Frage 13**
#
# Was gibt dieser Code aus?
# ```python
# import math
# print(math.hypot(0, 0))
# ```
# A) `0.0`
# B) `0`
# C) `None`
# D) `TypeError`

# %% [markdown]
# **Frage 14**
#
# Was gibt dieser Code aus?
# ```python
# import math
# print(math.sqrt(2) == 2**0.5)
# ```
# A) `False`
# B) `True`
# C) `None`
# D) `TypeError`

# %% [markdown]
# **Frage 15**
#
# Was gibt dieser Code aus?
# ```python
# import random
# random.seed(0)
# a = random.random()
# random.seed(0)
# b = random.random()
# print(a == b)
# ```
# A) `False`
# B) `None`
# C) `True`
# D) `TypeError`

# %% [markdown]
# **Frage 16**
#
# Was gibt dieser Code aus?
# ```python
# import random
# random.seed(5)
# print(random.randint(1, 1))
# ```
# A) `0`
# B) `5`
# C) `None`
# D) `1`

# %% [markdown]
# **Frage 17**
#
# Was gibt dieser Code aus?
# ```python
# import random
# random.seed(0)
# s = random.sample([1, 2, 3, 4, 5], 5)
# print(sorted(s) == [1, 2, 3, 4, 5])
# ```
# A) `True`
# B) `False`
# C) `None`
# D) `ValueError`

# %% [markdown]
# **Frage 18**
#
# Was gibt dieser Code aus?
# ```python
# import platform
# result = platform.python_version_tuple()
# print(len(result) == 3, result[0] in ('3', '2'))
# ```
# A) `False True`
# B) `True True`
# C) `True False`
# D) `False False`

# %% [markdown]
# **Frage 19**
#
# Was gibt dieser Code aus?
# ```python
# import math
# print(type(math).__name__)
# ```
# A) `type`
# B) `object`
# C) `module`
# D) `ModuleType`

# %% [markdown]
# **Frage 20**
#
# Was gibt dieser Code aus?
# ```python
# import math
# import math
# print(math.floor(1.5))
# ```
# A) `ImportError`
# B) `None`
# C) `0`
# D) `1`

# %% [markdown]
# ---
# ## Sektion 2: Exceptions

# %% [markdown]
# **Frage 21**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     raise ValueError('v')
# except Exception:
#     print('Exception')
# except ValueError:
#     print('ValueError')
# ```
# A) `Exception`
# B) `ValueError`
# C) `v`
# D) Beide werden ausgegeben

# %% [markdown]
# **Frage 22**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     raise ZeroDivisionError
# except ArithmeticError:
#     print('arithmetic')
# except ZeroDivisionError:
#     print('zero')
# ```
# A) `zero`
# B) `arithmetic`
# C) Beide werden ausgegeben
# D) `ZeroDivisionError`

# %% [markdown]
# **Frage 23**
#
# Was gibt dieser Code aus?
# ```python
# def f():
#     try:
#         raise RuntimeError
#     except RuntimeError:
#         return 1
#     finally:
#         return 2
#
# print(f())
# ```
# A) `RuntimeError`
# B) `1`
# C) `None`
# D) `2`

# %% [markdown]
# **Frage 24**
#
# Was gibt dieser Code aus?
# ```python
# result = []
# try:
#     result.append('try')
# except:
#     result.append('except')
# else:
#     result.append('else')
# finally:
#     result.append('finally')
# print(result)
# ```
# A) `['try', 'finally']`
# B) `['try', 'except', 'finally']`
# C) `['try', 'else', 'finally']`
# D) `['try', 'else']`

# %% [markdown]
# **Frage 25**
#
# Was gibt dieser Code aus?
# ```python
# def f():
#     try:
#         try:
#             raise ValueError
#         except TypeError:
#             return 'inner'
#     except ValueError:
#         return 'outer'
#
# print(f())
# ```
# A) `inner`
# B) `outer`
# C) `ValueError`
# D) `None`

# %% [markdown]
# **Frage 26**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     raise Exception(1, 2, 3)
# except Exception as e:
#     print(e.args[1])
# ```
# A) `1`
# B) `3`
# C) `2`
# D) `(1, 2, 3)`

# %% [markdown]
# **Frage 27**
#
# Was gibt dieser Code aus?
# ```python
# def f():
#     try:
#         raise ValueError('orig')
#     except ValueError as e:
#         raise ValueError('new') from e
#
# try:
#     f()
# except ValueError as e:
#     print(str(e))
# ```
# A) `orig`
# B) `orig new`
# C) `ValueError`
# D) `new`

# %% [markdown]
# **Frage 28**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     x = 5
#     assert x > 10, f'got {x}'
# except AssertionError as e:
#     print(str(e))
# ```
# A) `got 5`
# B) `AssertionError`
# C) `False`
# D) `x > 10`

# %% [markdown]
# **Frage 29**
#
# Was gibt dieser Code aus?
# ```python
# class AppError(Exception):
#     def __init__(self, code):
#         self.code = code
#         super().__init__(f'error {code}')
#
# try:
#     raise AppError(404)
# except AppError as e:
#     print(e.code, str(e))
# ```
# A) `AppError 404`
# B) `404 error 404`
# C) `404 404`
# D) `error 404 404`

# %% [markdown]
# **Frage 30**
#
# Was gibt dieser Code aus?
# ```python
# print(issubclass(ZeroDivisionError, ArithmeticError))
# ```
# A) `False`
# B) `None`
# C) `True`
# D) `TypeError`

# %% [markdown]
# **Frage 31**
#
# Was gibt dieser Code aus?
# ```python
# def f(x):
#     try:
#         if x == 0: raise ZeroDivisionError
#         if x < 0: raise ValueError
#         return x
#     except (ZeroDivisionError, ValueError) as e:
#         return type(e).__name__
#
# print(f(0), f(-1), f(1))
# ```
# A) `ZeroDivisionError ValueError None`
# B) `0 -1 1`
# C) `error error 1`
# D) `ZeroDivisionError ValueError 1`

# %% [markdown]
# **Frage 32**
#
# Was gibt dieser Code aus?
# ```python
# ran = []
#
# def f():
#     try:
#         raise SystemExit(0)
#     finally:
#         ran.append('finally')
#
# try:
#     f()
# except SystemExit:
#     pass
#
# print(ran)
# ```
# A) `['finally']`
# B) `[]`
# C) `SystemExit`
# D) `['finally', 'except']`

# %% [markdown]
# **Frage 33**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     raise ValueError
# except ValueError as e:
#     print(e.args)
# ```
# A) `None`
# B) `()`
# C) `('')`
# D) `ValueError`

# %% [markdown]
# **Frage 34**
#
# Was gibt dieser Code aus?
# ```python
# results = []
# for exc in [ValueError, KeyboardInterrupt]:
#     try:
#         raise exc
#     except Exception:
#         results.append('Exception')
#     except:
#         results.append('bare')
# print(results)
# ```
# A) `['Exception', 'Exception']`
# B) `['bare', 'bare']`
# C) `['Exception', 'bare']`
# D) `['bare', 'Exception']`

# %% [markdown]
# **Frage 35**
#
# Was gibt dieser Code aus?
# ```python
# def f():
#     try:
#         return 1
#     finally:
#         x = 1 + 1
#         return x
#
# print(f())
# ```
# A) `1`
# B) `None`
# C) `3`
# D) `2`

# %% [markdown]
# **Frage 36**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     try:
#         raise ValueError('first')
#     except ValueError as e:
#         raise TypeError('second') from e
# except TypeError as e:
#     print(type(e.__cause__).__name__)
# ```
# A) `ValueError`
# B) `TypeError`
# C) `Exception`
# D) `None`

# %% [markdown]
# **Frage 37**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     assert True, 'never'
#     print('ok')
# except AssertionError:
#     print('fail')
# ```
# A) `fail`
# B) `never`
# C) `ok`
# D) `None`

# %% [markdown]
# **Frage 38**
#
# Was gibt dieser Code aus?
# ```python
# def f():
#     try:
#         try:
#             raise ValueError
#         finally:
#             return 'finally'
#     except ValueError:
#         return 'except'
#
# print(f())
# ```
# A) `except`
# B) `ValueError`
# C) `None`
# D) `finally`

# %% [markdown]
# **Frage 39**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     raise Exception('a', 'b')
# except Exception as e:
#     print(len(e.args), e.args[0])
# ```
# A) `1 a`
# B) `2 a`
# C) `2 b`
# D) `1 ('a', 'b')`

# %% [markdown]
# **Frage 40**
#
# Was gibt dieser Code aus?
# ```python
# class MyErr(Exception):
#     pass
#
# try:
#     raise MyErr('hello', 42)
# except MyErr as e:
#     print(e.args[1])
# ```
# A) `42`
# B) `hello`
# C) `('hello', 42)`
# D) `AttributeError`

# %% [markdown]
# ---
# ## Sektion 3: Strings

# %% [markdown]
# **Frage 41**
#
# Was gibt dieser Code aus?
# ```python
# print('abcde'[1:-1:2])
# ```
# A) `ace`
# B) `bcd`
# C) `bd`
# D) `bce`

# %% [markdown]
# **Frage 42**
#
# Was gibt dieser Code aus?
# ```python
# print('abcdef'[::-2])
# ```
# A) `fdb`
# B) `ace`
# C) `fed`
# D) `fec`

# %% [markdown]
# **Frage 43**
#
# Was gibt dieser Code aus?
# ```python
# s = 'python'
# print(s[len(s)//2:])
# ```
# A) `pyt`
# B) `ython`
# C) `thon`
# D) `hon`

# %% [markdown]
# **Frage 44**
#
# Was gibt dieser Code aus?
# ```python
# print(chr(ord('A') + 32))
# ```
# A) `A`
# B) `a`
# C) `33`
# D) `TypeError`

# %% [markdown]
# **Frage 45**
#
# Was gibt dieser Code aus?
# ```python
# print(ord('z') - ord('a'))
# ```
# A) `1`
# B) `26`
# C) `25`
# D) `122`

# %% [markdown]
# **Frage 46**
#
# Was gibt dieser Code aus?
# ```python
# print(''.join(chr(c) for c in range(65, 68)))
# ```
# A) `678`
# B) `abc`
# C) `65 66 67`
# D) `ABC`

# %% [markdown]
# **Frage 47**
#
# Was gibt dieser Code aus?
# ```python
# s = 'hello'
# try:
#     s[0] = 'H'
# except TypeError:
#     print('immutable')
# ```
# A) `immutable`
# B) `Hello`
# C) `hello`
# D) `AttributeError`

# %% [markdown]
# **Frage 48**
#
# Was gibt dieser Code aus?
# ```python
# print('  Hello World  '.strip().lower().split()[1])
# ```
# A) `hello`
# B) `world`
# C) `Hello`
# D) `World`

# %% [markdown]
# **Frage 49**
#
# Was gibt dieser Code aus?
# ```python
# print('aababc'.count('ab'))
# ```
# A) `3`
# B) `1`
# C) `2`
# D) `0`

# %% [markdown]
# **Frage 50**
#
# Was gibt dieser Code aus?
# ```python
# print('hello'.replace('l', 'r', 1))
# ```
# A) `herro`
# B) `hello`
# C) `rello`
# D) `herlo`

# %% [markdown]
# **Frage 51**
#
# Was gibt dieser Code aus?
# ```python
# print('hello'.find('x'))
# ```
# A) `-1`
# B) `None`
# C) `False`
# D) `ValueError`

# %% [markdown]
# **Frage 52**
#
# Was gibt dieser Code aus?
# ```python
# try:
#     print('hello'.index('x'))
# except ValueError:
#     print('not found')
# ```
# A) `-1`
# B) `not found`
# C) `None`
# D) `False`

# %% [markdown]
# **Frage 53**
#
# Was gibt dieser Code aus?
# ```python
# print('abcabcabc'.rfind('b'))
# ```
# A) `1`
# B) `4`
# C) `7`
# D) `8`

# %% [markdown]
# **Frage 54**
#
# Was gibt dieser Code aus?
# ```python
# print('123'.isdigit(), '12a'.isdigit())
# ```
# A) `False False`
# B) `True True`
# C) `False True`
# D) `True False`

# %% [markdown]
# **Frage 55**
#
# Was gibt dieser Code aus?
# ```python
# print('Hello World'.istitle())
# ```
# A) `True`
# B) `False`
# C) `None`
# D) `TypeError`

# %% [markdown]
# **Frage 56**
#
# Was gibt dieser Code aus?
# ```python
# print('  '.isspace(), ''.isspace())
# ```
# A) `False False`
# B) `True False`
# C) `True True`
# D) `False True`

# %% [markdown]
# **Frage 57**
#
# Was gibt dieser Code aus?
# ```python
# words = 'one two three'.split()
# print('-'.join(words[::-1]))
# ```
# A) `one-two-three`
# B) `three two one`
# C) `three-two-one`
# D) `['three', 'two', 'one']`

# %% [markdown]
# **Frage 58**
#
# Was gibt dieser Code aus?
# ```python
# s = 'abcdef'
# print(s[-4:-1])
# ```
# A) `def`
# B) `bcde`
# C) `abcde`
# D) `cde`

# %% [markdown]
# **Frage 59**
#
# Was gibt dieser Code aus?
# ```python
# print('abc' < 'abd', 'ABC' < 'abc')
# ```
# A) `True True`
# B) `True False`
# C) `False True`
# D) `False False`

# %% [markdown]
# **Frage 60**
#
# Was gibt dieser Code aus?
# ```python
# print(''.join(sorted('dcba')))
# ```
# A) `dcba`
# B) `abcd`
# C) `['a', 'b', 'c', 'd']`
# D) `abdc`

# %% [markdown]
# ---
# ## Sektion 4: OOP

# %% [markdown]
# **Frage 61**
#
# Was gibt dieser Code aus?
# ```python
# class Foo:
#     x = 1
#     def bar(self): pass
#
# print(list(Foo.__dict__.keys())[2])
# ```
# A) `x`
# B) `__module__`
# C) `bar`
# D) `__dict__`

# %% [markdown]
# **Frage 62**
#
# Was gibt dieser Code aus?
# ```python
# class A:
#     v = 10
#
# a = A()
# a.v = 99
# del a.v
# print(a.v)
# ```
# A) `10`
# B) `99`
# C) `AttributeError`
# D) `None`

# %% [markdown]
# **Frage 63**
#
# Was gibt dieser Code aus?
# ```python
# class C:
#     data = []
#
# a = C()
# b = C()
# a.data.append(1)
# print(len(b.data))
# ```
# A) `0`
# B) `2`
# C) `AttributeError`
# D) `1`

# %% [markdown]
# **Frage 64**
#
# Was gibt dieser Code aus?
# ```python
# class P:
#     def __init__(self):
#         self.__x = 5
#
# class C(P):
#     def get(self):
#         return self._P__x
#
# print(C().get())
# ```
# A) `AttributeError`
# B) `5`
# C) `None`
# D) `0`

# %% [markdown]
# **Frage 65**
#
# Was gibt dieser Code aus?
# ```python
# class A:
#     def f(self): return 'A'
# class B(A):
#     def f(self): return 'B' + super().f()
# class C(A):
#     def f(self): return 'C' + super().f()
# class D(B, C):
#     def f(self): return 'D' + super().f()
#
# print(D().f())
# ```
# A) `DBCA`
# B) `DBC`
# C) `DCBA`
# D) `DBA`

# %% [markdown]
# **Frage 66**
#
# Was gibt dieser Code aus?
# ```python
# class T:
#     cls_var = 42
#     def __init__(self):
#         self.inst_var = 1
#
# t = T()
# print('cls_var' in t.__dict__, 'inst_var' in t.__dict__)
# ```
# A) `True True`
# B) `True False`
# C) `False True`
# D) `False False`

# %% [markdown]
# **Frage 67**
#
# Was gibt dieser Code aus?
# ```python
# def f():
#     try:
#         return 'try'
#     finally:
#         return 'finally'
#
# print(f())
# ```
# A) `try`
# B) `None`
# C) `try finally`
# D) `finally`

# %% [markdown]
# **Frage 68**
#
# Was gibt dieser Code aus?
# ```python
# class A:
#     pass
#
# print(issubclass(A, A))
# ```
# A) `False`
# B) `True`
# C) `None`
# D) `TypeError`

# %% [markdown]
# **Frage 69**
#
# Was gibt dieser Code aus?
# ```python
# class A:
#     pass
#
# print(A.__bases__[0].__name__)
# ```
# A) `object`
# B) `type`
# C) `A`
# D) `None`

# %% [markdown]
# **Frage 70**
#
# Was gibt dieser Code aus?
# ```python
# class X:
#     def __init__(self):
#         self.__secret = 1
#
# x = X()
# print(hasattr(x, '__secret'), hasattr(x, '_X__secret'))
# ```
# A) `True True`
# B) `True False`
# C) `False True`
# D) `False False`

# %% [markdown]
# **Frage 71**
#
# Was gibt dieser Code aus?
# ```python
# class A:
#     def __str__(self): return 'A'
# class B(A):
#     def __str__(self): return 'B+' + super().__str__()
# class C(B):
#     pass
#
# print(str(C()))
# ```
# A) `A`
# B) `B+A`
# C) `C`
# D) `B+A+C`

# %% [markdown]
# **Frage 72**
#
# Was gibt dieser Code aus?
# ```python
# class K:
#     n = 0
#
# k = K()
# k.n += 1
# print(k.n, K.n)
# ```
# A) `1 1`
# B) `0 1`
# C) `0 0`
# D) `1 0`

# %% [markdown]
# **Frage 73**
#
# Was gibt dieser Code aus?
# ```python
# class A: pass
# class B(A): pass
# class C(B): pass
#
# c = C()
# print(isinstance(c, A), c is not None)
# ```
# A) `True True`
# B) `False True`
# C) `True False`
# D) `False False`

# %% [markdown]
# **Frage 74**
#
# Was gibt dieser Code aus?
# ```python
# class A: pass
# class B(A): pass
# class C(B): pass
#
# print([x.__name__ for x in C.__mro__])
# ```
# A) `['C', 'A', 'B', 'object']`
# B) `['C', 'B', 'object']`
# C) `['C', 'B', 'A', 'object']`
# D) `['C', 'B', 'A']`

# %% [markdown]
# **Frage 75**
#
# Was gibt dieser Code aus?
# ```python
# class G:
#     x = 'class'
#     def __init__(self):
#         self.x = 'instance'
#
# g = G()
# del g.x
# print(g.x)
# ```
# A) `AttributeError`
# B) `class`
# C) `None`
# D) `instance`

# %% [markdown]
# **Frage 76**
#
# Was gibt dieser Code aus?
# ```python
# class A:
#     def __init__(self):
#         self.__x = 1
#         self.__y = 2
#
# a = A()
# print(sorted(k for k in a.__dict__))
# ```
# A) `['__x', '__y']`
# B) `['_x', '_y']`
# C) `['x', 'y']`
# D) `['_A__x', '_A__y']`

# %% [markdown]
# **Frage 77**
#
# Was gibt dieser Code aus?
# ```python
# class Animal:
#     def __init__(self):
#         self.alive = True
# class Mammal(Animal):
#     def __init__(self):
#         super().__init__()
#         self.warm = True
# class Dog(Mammal):
#     def __init__(self):
#         super().__init__()
#         self.legs = 4
#
# d = Dog()
# print(d.alive, d.warm, d.legs)
# ```
# A) `True True 4`
# B) `AttributeError`
# C) `True False 4`
# D) `None None 4`

# %% [markdown]
# **Frage 78**
#
# Was gibt dieser Code aus?
# ```python
# class Counter:
#     n = 0
#     def __init__(self):
#         Counter.n += 1
#     def __del__(self):
#         Counter.n -= 1
#
# a = Counter()
# b = Counter()
# del a
# print(Counter.n)
# ```
# A) `2`
# B) `0`
# C) `1`
# D) `3`

# %% [markdown]
# **Frage 79**
#
# Was gibt dieser Code aus?
# ```python
# class Base:
#     x = 'base'
# class Child(Base):
#     pass
#
# c = Child()
# c.x = 'child_inst'
# print(c.x, Child.x, Base.x)
# ```
# A) `child_inst child_inst base`
# B) `child_inst base base`
# C) `base base base`
# D) `child_inst base child_inst`

# %% [markdown]
# **Frage 80**
#
# Was gibt dieser Code aus?
# ```python
# class A:
#     pass
# class B(A):
#     pass
#
# print(type(B.__bases__[0]))
# ```
# A) `<class 'object'>`
# B) `<class 'B'>`
# C) `<class 'A'>`
# D) `<class 'type'>`

# %% [markdown]
# ---
# ## Sektion 5: List Comprehensions, Lambda, Closures, I/O

# %% [markdown]
# **Frage 81**
#
# Was gibt dieser Code aus?
# ```python
# funcs = []
# for i in range(3):
#     funcs.append(lambda: i)
# print([f() for f in funcs])
# ```
# A) `[0, 1, 2]`
# B) `[2, 2, 2]`
# C) `[0, 0, 0]`
# D) `[3, 3, 3]`

# %% [markdown]
# **Frage 82**
#
# Was gibt dieser Code aus?
# ```python
# funcs = [lambda x, n=n: x + n for n in range(3)]
# print([f(10) for f in funcs])
# ```
# A) `[12, 12, 12]`
# B) `[10, 11, 12]`
# C) `[13, 13, 13]`
# D) `[10, 10, 10]`

# %% [markdown]
# **Frage 83**
#
# Was gibt dieser Code aus?
# ```python
# print([x for x in range(10) if x % 2 == 0 if x % 3 == 0])
# ```
# A) `[0, 2, 4, 6, 8]`
# B) `[0, 3, 6, 9]`
# C) `[0, 6]`
# D) `[6]`

# %% [markdown]
# **Frage 84**
#
# Was gibt dieser Code aus?
# ```python
# result = [[j for j in range(i)] for i in range(1, 4)]
# print(result[2])
# ```
# A) `[0, 1]`
# B) `[0, 1, 2, 3]`
# C) `[0, 1, 2]`
# D) `[1, 2, 3]`

# %% [markdown]
# **Frage 85**
#
# Was gibt dieser Code aus?
# ```python
# f = lambda *args: sum(args)
# print(f(1, 2, 3, 4))
# ```
# A) `TypeError`
# B) `(1, 2, 3, 4)`
# C) `24`
# D) `10`

# %% [markdown]
# **Frage 86**
#
# Was gibt dieser Code aus?
# ```python
# def outer():
#     x = 10
#     def inner():
#         nonlocal x
#         x += 1
#         return x
#     return inner
#
# f = outer()
# print(f(), f(), f())
# ```
# A) `10 11 12`
# B) `11 11 11`
# C) `11 12 13`
# D) `10 10 10`

# %% [markdown]
# **Frage 87**
#
# Was gibt dieser Code aus?
# ```python
# def make(n):
#     return lambda x: x ** n
#
# ops = [make(i) for i in range(1, 4)]
# print([op(2) for op in ops])
# ```
# A) `[2, 2, 2]`
# B) `[2, 4, 8]`
# C) `[1, 2, 3]`
# D) `[2, 4, 6]`

# %% [markdown]
# **Frage 88**
#
# Was gibt dieser Code aus?
# ```python
# data = [1, 2, 3, 4, 5]
# result = list(filter(None, [x - 3 for x in data]))
# print(result)
# ```
# A) `[1, 2, 3, 4, 5]`
# B) `[-2, -1, 1, 2]`
# C) `[1, 2]`
# D) `[-2, -1, 0, 1, 2]`

# %% [markdown]
# **Frage 89**
#
# Was gibt dieser Code aus?
# ```python
# pairs = [(1, 'b'), (2, 'a'), (3, 'c')]
# pairs.sort(key=lambda p: p[1])
# print([p[0] for p in pairs])
# ```
# A) `[1, 2, 3]`
# B) `[2, 1, 3]`
# C) `[3, 1, 2]`
# D) `[2, 3, 1]`

# %% [markdown]
# **Frage 90**
#
# Was gibt dieser Code aus?
# ```python
# def counter():
#     n = 0
#     def inc():
#         nonlocal n
#         n += 1
#         return n
#     return inc
#
# a = counter()
# b = counter()
# a(); a()
# b()
# print(a(), b())
# ```
# A) `2 1`
# B) `3 2`
# C) `3 1`
# D) `2 2`

# %% [markdown]
# **Frage 91**
#
# Was gibt dieser Code aus?
# ```python
# print(list(map(lambda x: x**2,
#     filter(lambda x: x % 2 != 0, range(6)))))
# ```
# A) `[0, 4, 16]`
# B) `[1, 9, 25]`
# C) `[1, 3, 5]`
# D) `[0, 1, 4, 9, 16, 25]`

# %% [markdown]
# **Frage 92**
#
# Was gibt dieser Code aus?
# ```python
# xs = [1, 2, 3]
# ys = [4, 5, 6]
# print(list(map(lambda a, b: a * b, xs, ys)))
# ```
# A) `[5, 7, 9]`
# B) `[1, 4, 2, 5, 3, 6]`
# C) `[4, 10, 18]`
# D) `TypeError`

# %% [markdown]
# **Frage 93**
#
# Was gibt dieser Code aus?
# ```python
# print([x if x > 0 else -x for x in [-2, -1, 0, 1, 2]])
# ```
# A) `[-2, -1, 0, 1, 2]`
# B) `[2, 1, 0, 1, 2]`
# C) `[2, 1, 1, 2]`
# D) `[0, 0, 0, 1, 2]`

# %% [markdown]
# **Frage 94**
#
# Was gibt dieser Code aus?
# ```python
# add = lambda x: lambda y: lambda z: x + y + z
# print(add(1)(2)(3))
# ```
# A) `(1, 2, 3)`
# B) `123`
# C) `TypeError`
# D) `6`

# %% [markdown]
# **Frage 95**
#
# Was gibt dieser Code aus?
# ```python
# def f(x, fn=lambda x: x):
#     return fn(x)
#
# print(f(5), f(5, lambda x: x * 2))
# ```
# A) `5 5`
# B) `5 10`
# C) `10 5`
# D) `TypeError`

# %% [markdown]
# **Frage 96**
#
# Was gibt dieser Code aus?
# ```python
# import tempfile, os
# with tempfile.NamedTemporaryFile(mode='w', suffix='.txt', delete=False) as f:
#     f.write('line1\nline2\n')
#     name = f.name
# with open(name) as f:
#     lines = f.readlines()
# os.unlink(name)
# print(len(lines), lines[0].strip())
# ```
# A) `1 line1`
# B) `3 line1`
# C) `2 line1`
# D) `2 line1\n`

# %% [markdown]
# **Frage 97**
#
# Was gibt dieser Code aus?
# ```python
# import tempfile, os
# with tempfile.NamedTemporaryFile(mode='w', suffix='.txt', delete=False) as f:
#     f.write('hello')
#     name = f.name
# with open(name, 'a') as f:
#     f.write(' world')
# with open(name) as f:
#     print(f.read())
# os.unlink(name)
# ```
# A) `world`
# B) `hello`
# C) `hello world`
# D) `hello\nworld`

# %% [markdown]
# **Frage 98**
#
# Was gibt dieser Code aus?
# ```python
# import tempfile, os
# with tempfile.NamedTemporaryFile(mode='w', suffix='.txt', delete=False) as f:
#     f.write('a\nb\nc')
#     name = f.name
# with open(name) as f:
#     first = f.readline()
#     second = f.readline()
# os.unlink(name)
# print(repr(first), repr(second))
# ```
# A) `'a' 'b'`
# B) `'a\n' 'b\n'`
# C) `'a\n' 'b'`
# D) `'a' 'b\n'`

# %% [markdown]
# **Frage 99**
#
# Welcher Modus öffnet eine Datei zum Lesen **und** Schreiben, ohne den Inhalt zu löschen?
# ```python
# f = open('data.txt', ???)
# ```
# A) `'w+'`
# B) `'r+'`
# C) `'a+'`
# D) `'x'`

# %% [markdown]
# **Frage 100**
#
# Was gibt dieser Code aus?
# ```python
# result = []
# for i in range(3):
#     def f(x, i=i):
#         return x + i
#     result.append(f)
# print([fn(10) for fn in result])
# ```
# A) `[12, 12, 12]`
# B) `[10, 10, 10]`
# C) `[10, 11, 12]`
# D) `[13, 13, 13]`
