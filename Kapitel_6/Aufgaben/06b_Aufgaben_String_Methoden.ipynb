# %% [markdown]
# # Aufgaben: String Methoden

# %% [markdown]
# <div style="display:flex;justify-content:space-between;align-items:center;background:#0d0d0f;border:1px solid #1e1e24;border-left:4px solid #4fc3f7;border-radius:6px;padding:clamp(1rem,2.5vw,1.8rem) clamp(1.2rem,3vw,2.4rem);margin-bottom:2rem;position:relative;overflow:hidden;box-shadow:0 4px 32px rgba(0,0,0,0.5);font-family:'Segoe UI',sans-serif;">
# <div style="position:absolute;top:0;left:0;right:0;bottom:0;background:radial-gradient(ellipse at 0% 50%,rgba(79,195,247,0.07) 0%,transparent 60%);pointer-events:none;"></div>
# <div style="display:flex;flex-direction:column;gap:0.3rem;">
# <p style="font-size:clamp(1.3rem,3.5vw,2.4rem);color:#f0f0f5;margin:0;line-height:1.1;font-weight:700;letter-spacing:-0.01em;">Aufgaben: String-Methoden</p>
# <p style="font-size:clamp(0.75rem,1.6vw,1rem);color:#7a7a90;margin:0;letter-spacing:0.04em;font-weight:300;">Development Expert Python &nbsp;|&nbsp; PCAP 3.3 &nbsp;|&nbsp; Kapitel 6: Strings &nbsp;|&nbsp; Notebook 06b</p>
# </div>
# </div>

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 1</span>
# isxxx(): Pruefmethoden
# </span>
# </div>

# %% [markdown]
# 1. Teste folgende Strings mit `isdigit()`, `isalpha()`, `isalnum()`, `isspace()`:
#    `'123'`, `'abc'`, `'abc123'`, `'  '`, `''`, `'-5'`, `'3.14'`, `'²'`
#    Gib die Ergebnisse tabellarisch aus.
# 2. Erklaere als Kommentar:
#    - Warum gibt `'-5'.isdigit()` `False` zurueck?
#    - Warum gibt `'3.14'.isdigit()` `False` zurueck?
#    - Was gibt `''.isdigit()` zurueck und warum?
# 3. Schreibe eine Funktion `ist_ganze_zahl(text)`, die `True` zurueckgibt
#    wenn `text` eine ganze Zahl darstellt (inkl. negativer Zahlen wie `'-5'`).
#    Nutze `isdigit()` und Slicing.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 2</span>
# isupper(), islower(), istitle()
# </span>
# </div>

# %% [markdown]
# 1. Teste folgende Strings mit `isupper()`, `islower()`, `istitle()`:
#    `'PYTHON'`, `'python'`, `'Python'`, `'Python Ist Toll'`, `'Python ist toll'`,
#    `'ABC123'`, `'abc123'`, `''`
# 2. Schreibe eine Funktion `normalisiere_titel(text)`, die:
#    - Fuehrende und abschliessende Leerzeichen entfernt
#    - Den ersten Buchstaben jedes Wortes grossschreibt
#    - Den Rest kleinschreibt
#    Nutze Methoden, kein manuelles Iterieren.
# 3. Vorhersage: Was gibt `'Hello World'.istitle()` aus? Was `'Hello world'`?
#    Begruende als Kommentar.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 3</span>
# split() und join()
# </span>
# </div>

# %% [markdown]
# 1. Zerlege `'Aldric,Lyria,Thorn,Sera'` mit `split()` in eine Liste.
# 2. Zerlege `'   Helden   der   Gilde   '` mit `split()` ohne Argument.
#    Was passiert mit den mehrfachen Leerzeichen? Erklaere als Kommentar.
# 3. Zerlege `'Held/Krieger/Stufe-5'` nur am ersten `/`.
#    Nutze `split('/', 1)`.
# 4. Verbinde `['Aldric', 'Lyria', 'Thorn']` zu:
#    - `'Aldric, Lyria, Thorn'` (Komma-Leerzeichen)
#    - `'Aldric | Lyria | Thorn'` (Pipe mit Leerzeichen)
#    - `'AldricLyriaThron'` (kein Trennzeichen)
# 5. PCAP-Falle: Was ist der Fehler in `['a', 'b'].join('-')`?
#    Erklaere und zeige die korrekte Schreibweise.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 4</span>
# sort() und sorted(): PCAP-Falle
# </span>
# </div>

# %% [markdown]
# 1. Gegeben: `helden = ['Thorn', 'Aldric', 'Lyria', 'Mira', 'Bjorn']`
# 2. Sortiere mit `sorted()` und speichere das Ergebnis. Gib Original und Kopie aus.
# 3. Sortiere mit `.sort()` direkt auf der Liste.
# 4. PCAP-Falle: Was ist das Problem in folgendem Code?
# ```python
# helden = ['Thorn', 'Aldric', 'Lyria']
# sortiert = helden.sort()
# print(sortiert)
# ```
#    Erklaere als Kommentar und zeige die Korrektur.
# 5. Sortiere `helden` nach Laenge des Namens (kuerzeste zuerst).
#    Bei gleicher Laenge alphabetisch.
# 6. Sortiere `helden` alphabetisch ohne Ruecksicht auf Gross-/Kleinschreibung.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 5</span>
# Vorhersage: String-Methoden
# </span>
# </div>

# %% [markdown]
# Den Code nicht ausfuehren. Ausgabe als Kommentar schreiben, dann pruefen.
#
# **5.1**
# ```python
# s = 'Python ist toll'
# print(s.split())
# print(s.split('t'))
# print(len(s.split()))
# ```
#
# **5.2**
# ```python
# helden = ['Lyria', 'Aldric', 'Thorn']
# print(', '.join(helden))
# print(''.join(sorted(helden)))
# ```
#
# **5.3**
# ```python
# s = 'aAbBcC'
# print(s.upper())
# print(s.lower())
# print(s.swapcase())
# print('hello world'.title())
# ```
#
# **5.4**
# ```python
# helden = ['Thorn', 'Aldric', 'Lyria']
# helden.sort()
# print(helden)
# ergebnis = helden.sort(reverse=True)
# print(ergebnis)
# print(helden)
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 6</span>
# find(), rfind() und index()
# </span>
# </div>

# %% [markdown]
# Gegeben: `text = 'Python ist toll und Python macht Spass'`
#
# 1. Finde die Position des ersten `'Python'` mit `find()`.
# 2. Finde die Position des zweiten `'Python'` mit `find(start)`.
# 3. Finde die Position des letzten `'Python'` mit `rfind()`.
# 4. Suche nach `'Java'`: was gibt `find()` zurueck? Was gibt `index()` zurueck?
#    Fange den Fehler von `index()` ab.
# 5. Erklaere als Kommentar: Wann verwendet man `find()`, wann `index()`?
# 6. Schreibe eine Funktion `alle_positionen(text, teilstring)`,
#    die eine Liste aller Startpositionen von `teilstring` in `text` zurueckgibt.
#    Nutze `find()` mit Startposition in einer Schleife.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 7</span>
# strip(), replace(), startswith(), endswith()
# </span>
# </div>

# %% [markdown]
# 1. Bereinige folgende Strings mit `strip()`, `lstrip()`, `rstrip()`:
#    `'   Hallo   '`, `'###Titel###'`, `'\n\tText\n'`
# 2. Ersetze in `'Aetherion ist eine Welt. Aetherion ist gross.'`:
#    - `'Aetherion'` durch `'Myria'`
#    - nur das erste Vorkommen von `'ist'` durch `'war'`
# 3. Schreibe eine Funktion `bereinige_eingaben(eingaben)`, die eine Liste
#    von Strings entgegennimmt, jeden Eintrag stripped und leere Strings entfernt.
# 4. Nutze `startswith()` und `endswith()`:
#    - Filtere aus einer Liste nur die Strings die mit `'Held'` beginnen.
#    - Pruefe ob eine Datei auf `'.ipynb'` endet.
#    - `startswith()` akzeptiert auch ein Tuple: filtere Strings die mit
#      `'A'` oder `'E'` beginnen.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 8</span>
# Fehler finden: String-Methoden
# </span>
# </div>

# %% [markdown]
# Im folgenden Code stecken vier Fehler. Finde und korrigiere alle vier.
#
# ```python
# helden = ['Thorn', 'Aldric', 'Lyria']
#
# # Fehler 1
# sortiert = helden.sort()
# print(sortiert[0])
#
# # Fehler 2
# ausgabe = helden.join(', ')
#
# # Fehler 3
# text = 'Python ist toll'
# pos = text.index('Java')
#
# # Fehler 4
# eingabe = '123'
# if eingabe.isdigit:
#     print('Ist eine Zahl')
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 9</span>
# Methoden kombinieren
# </span>
# </div>

# %% [markdown]
# 1. Schreibe eine Funktion `parse_csv_zeile(zeile)`, die eine CSV-Zeile
#    wie `'  Aldric , Krieger , 100 '` verarbeitet:
#    - Felder an `,` splitten
#    - Jeden Feldwert strippen
#    - Zurueckgeben als Liste bereinigter Strings
# 2. Schreibe eine Funktion `woerter_zaehlen(text)`, die ein Dictionary
#    mit Wort-Haeufigkeiten zurueckgibt (Grossschreibung ignorieren).
# 3. Schreibe eine Funktion `snake_zu_camel(name)`, die einen Snake-Case-String
#    in CamelCase umwandelt.
#    Teste: `snake_zu_camel('held_erstellen_factory')` ergibt `'HeldErstellenFactory'`.
#    Nutze `split()`, `title()` und `join()`.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 10</span>
# Kombination: Textnormalisierer
# </span>
# </div>

# %% [markdown]
# Schreibe eine Funktion `normalisiere(text)`, die einen rohen Eingabetext
# bereinigt und strukturiert zurueckgibt:
#
# 1. Fuehrende/abschliessende Leerzeichen entfernen
# 2. Mehrfache Leerzeichen zu einem zusammenfassen
# 3. Jeden Satz (getrennt durch `'.'`) mit grossem Anfangsbuchstaben schreiben
# 4. Woerter die komplett gross geschrieben sind, auf Titelschreibung setzen
# 5. Das Ergebnis zurueckgeben
#
# Teste:
# ```python
# roh = '  hallo welt.  PYTHON ist   toll.  aetherion  '
# print(normalisiere(roh))
# # 'Hallo welt. Python ist toll. Aetherion'
# ```
#
# Dokumentation: https://docs.python.org/3/library/stdtypes.html#string-methods
