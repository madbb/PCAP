# %% [markdown]
# # Aufgaben: Strings Encoding

# %% [markdown]
# <div style="display:flex;justify-content:space-between;align-items:center;background:#0d0d0f;border:1px solid #1e1e24;border-left:4px solid #4fc3f7;border-radius:6px;padding:clamp(1rem,2.5vw,1.8rem) clamp(1.2rem,3vw,2.4rem);margin-bottom:2rem;position:relative;overflow:hidden;box-shadow:0 4px 32px rgba(0,0,0,0.5);font-family:'Segoe UI',sans-serif;">
# <div style="position:absolute;top:0;left:0;right:0;bottom:0;background:radial-gradient(ellipse at 0% 50%,rgba(79,195,247,0.07) 0%,transparent 60%);pointer-events:none;"></div>
# <div style="display:flex;flex-direction:column;gap:0.3rem;">
# <p style="font-size:clamp(1.3rem,3.5vw,2.4rem);color:#f0f0f5;margin:0;line-height:1.1;font-weight:700;letter-spacing:-0.01em;">Aufgaben: Strings, Encoding und Grundoperationen</p>
# <p style="font-size:clamp(0.75rem,1.6vw,1rem);color:#7a7a90;margin:0;letter-spacing:0.04em;font-weight:300;">Development Expert Python &nbsp;|&nbsp; PCAP 3.1 / 3.2 &nbsp;|&nbsp; Kapitel 6: Strings &nbsp;|&nbsp; Notebook 06a</p>
# </div>
# </div>

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 1</span>
# ord() und chr()
# </span>
# </div>

# %% [markdown]
# 1. Gib den Unicode-Codepoint folgender Zeichen aus: `'A'`, `'a'`, `'Z'`, `'0'`, `' '`.
# 2. Gib das Zeichen zu folgenden Codepoints aus: `65`, `97`, `48`, `64`, `128512`.
# 3. Zeige, dass `ord()` und `chr()` Umkehrfunktionen sind:
#    `chr(ord('X')) == 'X'` und `ord(chr(9999)) == 9999`.
# 4. Schreibe eine Funktion `buchstabe_verschieben(zeichen, schritte)`,
#    die einen Buchstaben um `schritte` Positionen im Alphabet verschiebt.
#    Beispiel: `buchstabe_verschieben('A', 3)` ergibt `'D'`.
# 5. Erklaere als Kommentar: Warum ergibt `'A' < 'a'` in Python `True`?

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 2</span>
# ASCII und Unicode
# </span>
# </div>

# %% [markdown]
# 1. Gib alle druckbaren ASCII-Zeichen aus (Codepoints 32 bis 126).
#    Format: `'32: (Leerzeichen)'`, `'65: A'` usw.
# 2. Pruefe: Welche der folgenden Zeichen liegen ausserhalb des ASCII-Bereichs?
#    `'A'`, `'ä'`, `'€'`, `'中'`, `'!'`
#    Schreibe eine Funktion `ist_ascii(zeichen)` die `True` zurueckgibt
#    wenn der Codepoint zwischen 0 und 127 liegt.
# 3. Schreibe eine Funktion `nur_ascii(text)`, die alle Nicht-ASCII-Zeichen
#    aus einem String entfernt und den bereinigten String zurueckgibt.
# 4. Teste: `nur_ascii('Hallo Wörld!')` ergibt `'Hallo Wrld!'`.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 3</span>
# encode() und decode()
# </span>
# </div>

# %% [markdown]
# 1. Encode den String `'Hallo'` mit UTF-8. Gib den `bytes`-Wert und `type()` aus.
# 2. Encode `'Straße'` mit UTF-8 und mit Latin-1.
#    Vergleiche die Laenge der Ergebnisse. Erklaere den Unterschied als Kommentar.
# 3. Versuche `'Straße'.encode('ascii')`. Fange den `UnicodeEncodeError` ab
#    und gib die Fehlermeldung aus.
# 4. Decode `b'Hallo'` zurueck zu einem String.
# 5. Schreibe eine Funktion `zeige_bytes(text, encoding='utf-8')`,
#    die jeden Buchstaben mit seinen Byte-Werten ausgibt:
# ```
# H -> b'H' (1 Byte)
# ä -> b'\xc3\xa4' (2 Bytes)
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 4</span>
# Indexing und Slicing
# </span>
# </div>

# %% [markdown]
# Gegeben: `text = 'Aetherion'`
#
# 1. Gib aus: erstes Zeichen, letztes Zeichen, zweitletztes Zeichen.
# 2. Gib folgende Slices aus und erklaere jeden als Kommentar:
#    `text[2:6]`, `text[:4]`, `text[4:]`, `text[-3:]`, `text[::2]`, `text[::-1]`
# 3. Strings sind immutable. Versuche `text[0] = 'a'`, fange den Fehler ab
#    und erklaere als Kommentar warum das nicht funktioniert.
# 4. Schreibe eine Funktion `kehre_um(text)` die einen String umkehrt.
#    Nutze Slicing, nicht `reversed()`.
# 5. Schreibe eine Funktion `ist_palindrom(text)` die prueft ob ein String
#    vorwaerts und rueckwaerts gelesen gleich ist.
#    Teste mit `'racecar'`, `'Aetherion'`, `'madam'`.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 5</span>
# Vorhersage: Slicing und Operatoren
# </span>
# </div>

# %% [markdown]
# Den Code nicht ausfuehren. Ausgabe als Kommentar schreiben, dann pruefen.
#
# **5.1**
# ```python
# s = 'Python'
# print(s[1])
# print(s[-2])
# print(s[1:4])
# print(s[::-1])
# ```
#
# **5.2**
# ```python
# s = 'Aetherion'
# print(s[2:7:2])
# print(s[-4:-1])
# print(len(s))
# ```
#
# **5.3**
# ```python
# print('A' < 'B')
# print('a' < 'B')
# print('abc' == 'abc')
# print('abc' < 'abd')
# print(ord('a') - ord('A'))
# ```
#
# **5.4**
# ```python
# s = 'Python'
# print('py' in s)
# print('Py' in s)
# print('yt' not in s)
# print(s * 2 == s + s)
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 6</span>
# Operatoren: in, not in, +, *, Vergleiche
# </span>
# </div>

# %% [markdown]
# 1. Gegeben: `text = 'Aetherion ist eine magische Welt'`
#    Pruefe mit `in` und `not in`:
#    - Enthaelt der Text `'magisch'`?
#    - Enthaelt der Text `'Aether'`?
#    - Fehlt `'Dunkel'` im Text?
# 2. Schreibe eine Funktion `zaehle_vorkommen(text, teilstring)`,
#    die zaehlt wie oft `teilstring` in `text` vorkommt.
#    Keine Verwendung von `.count()` -- nutze eine Schleife mit `in`.
# 3. Sortiere folgende Strings nach ihrem Unicode-Codepoint des ersten Zeichens:
#    `woerter = ['zebra', 'Affe', 'mammut', 'Biene', 'elefant']`
#    Erklaere das Ergebnis als Kommentar.
# 4. Schreibe eine Funktion `caesar_verschluesseln(text, verschiebung)`,
#    die jeden Kleinbuchstaben im Text um `verschiebung` Positionen verschiebt.
#    Nicht-Buchstaben bleiben unveraendert. Nutze `ord()` und `chr()`.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 7</span>
# Escape-Sequenzen
# </span>
# </div>

# %% [markdown]
# 1. Schreibe einen String der folgende Ausgabe erzeugt (genau so, inkl. Anführungszeichen):
# ```
# Er sagte: "Willkommen in Aetherion!"
# ```
# 2. Schreibe einen String der einen Tabulator zwischen `'Name'` und `'HP'` enthaelt
#    und dann in einer neuen Zeile `'Aldric'` und `'100'` mit Tabulator getrennt.
# 3. Was gibt folgender Code aus?
# ```python
# print('A\nB\tC\\D')
# ```
#    Berechne die Ausgabe zuerst als Kommentar, dann pruefen.
# 4. Was ist der Unterschied zwischen `'\n'` und `r'\n'`?
#    Gib `len('\n')` und `len(r'\n')` aus und erklaere.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 8</span>
# Iteration ueber Strings
# </span>
# </div>

# %% [markdown]
# 1. Schreibe eine Funktion `zeichenstatistik(text)`, die ein Dictionary zurueckgibt
#    mit der Haeufigkeit jedes Zeichens im Text.
# 2. Schreibe eine Funktion `nur_buchstaben(text)`, die alle Zeichen ausser
#    Buchstaben entfernt. Nutze `chr()` um zu pruefen ob ein Zeichen ein
#    Buchstabe ist (Codepoint-Bereich, nicht `isalpha()`).
# 3. Schreibe eine Funktion `wort_laengen(satz)`, die eine Liste der Laenge
#    jedes Wortes zurueckgibt.
#    Teste: `wort_laengen('Aetherion ist toll')` ergibt `[9, 3, 4]`.
# 4. Schreibe eine Funktion `anagramm(wort1, wort2)`, die prueft ob zwei
#    Woerter Anagramme voneinander sind (selbe Buchstaben, andere Reihenfolge).
#    Teste: `anagramm('listen', 'silent')` ergibt `True`.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 9</span>
# Fehler finden: Strings
# </span>
# </div>

# %% [markdown]
# Im folgenden Code stecken vier Fehler. Finde und korrigiere alle vier.
#
# ```python
# text = 'Aetherion'
#
# # Fehler 1
# text[0] = 'a'
#
# # Fehler 2
# print(text[9])   # sollte das letzte Zeichen sein
#
# # Fehler 3
# zeichen = 'A'
# print(chr(zeichen))   # sollte den Codepoint ausgeben
#
# # Fehler 4
# encoded = 'Straße'.encode('ascii')   # soll ohne Fehler funktionieren
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 10</span>
# Kombination: Zeichenanalyse
# </span>
# </div>

# %% [markdown]
# Schreibe eine Funktion `text_analysieren(text)`, die ein Dictionary zurueckgibt mit:
# - `'laenge'`: Anzahl aller Zeichen
# - `'buchstaben'`: Anzahl der Buchstaben (a-z, A-Z und Umlaute via `isalpha()`)
# - `'ziffern'`: Anzahl der Ziffern (0-9)
# - `'ascii_anteil'`: Anteil der ASCII-Zeichen (0.0 bis 1.0)
# - `'haeufigste'`: das am haeufigsten vorkommende Zeichen (ohne Leerzeichen)
# - `'umkehrung'`: der Text rueckwaerts (Slicing)
#
# Teste:
# ```python
# ergebnis = text_analysieren('Aetherion 42!')
# print(ergebnis['laenge'])        # 13
# print(ergebnis['ascii_anteil'])  # 1.0
#
# ergebnis2 = text_analysieren('Straße 99')
# print(ergebnis2['ascii_anteil'])  # < 1.0 wegen 'ß'
# ```
#
# Dokumentation: https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str
