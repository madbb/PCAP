# %% [markdown]
# # Aufgaben: Mittelbach Aktuell

# %% [markdown]
# <div style="display:flex;justify-content:space-between;align-items:center;background:#0d0d0f;border:1px solid #1e1e24;border-left:4px solid #4fc3f7;border-radius:6px;padding:clamp(1rem,2.5vw,1.8rem) clamp(1.2rem,3vw,2.4rem);margin-bottom:2rem;position:relative;overflow:hidden;box-shadow:0 4px 32px rgba(0,0,0,0.5);font-family:'Segoe UI',sans-serif;">
# <div style="position:absolute;top:0;left:0;right:0;bottom:0;background:radial-gradient(ellipse at 0% 50%,rgba(79,195,247,0.07) 0%,transparent 60%);pointer-events:none;"></div>
# <div style="display:flex;flex-direction:column;gap:0.3rem;">
# <p style="font-size:clamp(1.3rem,3.5vw,2.4rem);color:#f0f0f5;margin:0;line-height:1.1;font-weight:700;letter-spacing:-0.01em;">Aufgaben: Dateioperationen mit mittelbach_aktuell.txt</p>
# <p style="font-size:clamp(0.75rem,1.6vw,1rem);color:#7a7a90;margin:0;letter-spacing:0.04em;font-weight:300;">Development Expert Python &nbsp;|&nbsp; PCAP 5.4 / 5.5 &nbsp;|&nbsp; Kapitel 7: I/O</p>
# </div>
# </div>

# %% [markdown]
# <div style="background:#080f17;border:1px solid #1a2e42;border-radius:8px;padding:1.4rem 1.8rem;margin-bottom:1.5rem;font-family:'Segoe UI',sans-serif;">
#
# <p style="font-size:1.05rem;font-weight:700;color:#4fc3f7;margin:0 0 0.8rem 0;letter-spacing:0.05em;text-transform:uppercase;">Datenbasis</p>
# <p style="color:#c5cae9;margin:0 0 0.7rem 0;line-height:1.7;font-size:0.95rem;">
# Alle Aufgaben arbeiten mit der Datei <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.4em;border-radius:3px;">mittelbach_aktuell.txt</code>.
# Die Datei liegt im selben Verzeichnis wie dieses Notebook und enthaelt eine fiktive Lokalzeitung
# mit fuenf Artikeln: Stadtrat, Feuerwehr, Volksfest, Stadtbibliothek und Wetterbericht.
# </p>
# <p style="color:#c5cae9;margin:0;line-height:1.7;font-size:0.95rem;">
# Alle Dateioperationen mit <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.4em;border-radius:3px;">encoding='utf-8'</code> und im <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.4em;border-radius:3px;">with</code>-Block ausfuehren.
# </p>
# </div>

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 1</span>
# Datei einlesen und Grundinformationen
# </span>
# </div>

# %% [markdown]
# 1. Lies den gesamten Inhalt der Datei mit `read()` in eine Variable `inhalt`.
# 2. Gib aus:
#    - Anzahl der Zeichen (Laenge des Strings)
#    - Anzahl der Zeilen (Anzahl `'\n'` im Text, oder via `splitlines()`)
#    - Anzahl der Woerter (split ohne Argument zaehlt alle Woerter)
#    - Die erste Zeile des Textes
#    - Die letzte Zeile des Textes
# 3. Erklaere als Kommentar: Was ist der Unterschied zwischen
#    `split('\n')` und `splitlines()`?

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 2</span>
# Zeilenweise lesen mit readline()
# </span>
# </div>

# %% [markdown]
# 1. Oeffne die Datei und lies sie mit `readline()` in einer Schleife
#    Zeile fuer Zeile, bis das Ende erreicht ist.
# 2. Gib dabei nur Zeilen aus, die nicht leer sind und nicht mit `---` beginnen.
# 3. Zaehle dabei mit, wie viele solcher nicht-leeren Inhaltszeilen es gibt.
# 4. Was gibt `readline()` zurueck wenn die Datei zu Ende ist?
#    Erklaere als Kommentar.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 3</span>
# readlines() und Zeilenverarbeitung
# </span>
# </div>

# %% [markdown]
# 1. Lies alle Zeilen mit `readlines()` in eine Liste `zeilen`.
# 2. Gib `type(zeilen)` und `type(zeilen[0])` aus.
# 3. Viele Zeilen enden mit `'\n'`. Entferne dieses Zeichen von allen Zeilen
#    mit einer List Comprehension und `strip()`.
# 4. Filtere nur Zeilen heraus, die eine Zahl enthalten.
#    Nutze eine List Comprehension mit `any(c.isdigit() for c in zeile)`.
# 5. Gib alle Zeilen mit Zahlen aus.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 4</span>
# Artikel extrahieren
# </span>
# </div>

# %% [markdown]
# Die Artikel in der Datei sind durch Zeilen mit `---` getrennt.
#
# 1. Lies die gesamte Datei ein.
# 2. Trenne den Text an den `---`-Trennlinien mit `split('---')`.
# 3. Bereinige jeden Artikel: `strip()` entfernt fuehrende und abschliessende Leerzeichen.
# 4. Filtere leere Eintraege heraus.
# 5. Gib aus:
#    - Wie viele Artikel gibt es?
#    - Den Titel jedes Artikels (erste Zeile des jeweiligen Blocks)

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 5</span>
# Zahlen aus dem Text extrahieren
# </span>
# </div>

# %% [markdown]
# 1. Lies die gesamte Datei ein.
# 2. Extrahiere alle Zahlen aus dem Text.
#    Nutze eine Schleife: Woerter splitten, dann pruefen ob ein Wort
#    nur aus Ziffern besteht (nach dem Entfernen von Satzzeichen mit `strip('.,:')`)
# 3. Gib alle gefundenen Zahlen als Liste von `int`-Werten aus.
# 4. Gib die groesste und die kleinste gefundene Zahl aus.
# 5. Was ist die Summe aller Zahlen im Text?

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 6</span>
# Personen-Erwaehnungen finden
# </span>
# </div>

# %% [markdown]
# 1. Lies die Datei zeilenweise.
# 2. Suche alle Zeilen, die einen der folgenden Namen enthalten:
# ```python
# personen = ['Kratzmann', 'Wendtner', 'Sonnleitner', 'Siebenkaes', 'Brenner']
# ```
# 3. Gib fuer jede gefundene Person aus:
#    - Den Namen
#    - Die Zeilennummer (ab 1 gezaehlt)
#    - Den Inhalt der Zeile (gestrippt)
# 4. Erstelle ein Dictionary `erwaehnt_in = {name: [zeilennummern]}` das
#    fuer jede Person alle Zeilennummern speichert, in denen sie vorkommt.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 7</span>
# Zusammenfassung schreiben
# </span>
# </div>

# %% [markdown]
# 1. Lies alle Artikel aus der Datei (wie in Aufgabe 4).
# 2. Erstelle eine neue Datei `zusammenfassung.txt` mit folgendem Inhalt:
#    - Kopfzeile: `'Mittelbach Aktuell - Zusammenfassung'`
#    - Eine Leerzeile
#    - Fuer jeden Artikel: die Nummer (1, 2, 3...) und den Titel
#    - Am Ende: `'Anzahl Artikel: X'`
# 3. Lies die erstellte Datei zur Kontrolle ein und gib sie aus.
# 4. Erklaere als Kommentar: Warum muss man `'\n'` explizit an
#    jede Zeile anhaengen?

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 8</span>
# Haeufigste Woerter ermitteln
# </span>
# </div>

# %% [markdown]
# 1. Lies die gesamte Datei ein und wandle alles in Kleinschreibung um.
# 2. Splitte den Text in einzelne Woerter.
# 3. Bereinige jedes Wort: `strip('.,:-!?"\'')`
# 4. Zaehle die Haeufigkeit jedes Wortes in einem Dictionary.
#    Ueberspringe dabei Woerter die kuerzer als 4 Zeichen sind
#    (damit 'und', 'der', 'die' usw. nicht die Liste dominieren).
# 5. Gib die 10 haeufigsten Woerter mit ihrer Anzahl aus,
#    sortiert nach Haeufigkeit absteigend.
#    Nutze `sorted()` mit einem Lambda als `key`.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 9</span>
# Zeilen anhaengen und Cursor
# </span>
# </div>

# %% [markdown]
# 1. Haenge mit Modus `'a'` drei neue Zeilen an die Datei an:
# ```
# ---
#
# ANZEIGE: Baeckerei Huber - Frische Broetchen seit 1952
# ```
# 2. Lies danach die gesamte Datei mit `read()` und pruefe,
#    dass die neuen Zeilen am Ende stehen.
# 3. Oeffne die Datei und lies sie zweimal hintereinander mit `read()`.
#    Was gibt der zweite Aufruf zurueck? Erklaere als Kommentar.
# 4. Nutze `seek(0)` um den Cursor zurueckzusetzen und lies erneut.
#    Gib die letzten 3 Zeilen des Inhalts aus.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 10</span>
# Kombination: Zeitungsanalyse-Report
# </span>
# </div>

# %% [markdown]
# Schreibe eine Funktion `analysiere_zeitung(eingabe_pfad, ausgabe_pfad)`, die:
#
# 1. Die Eingabedatei liest
# 2. Folgende Informationen ermittelt:
#    - Gesamtanzahl Zeichen, Woerter und Zeilen
#    - Anzahl der Artikel
#    - Titel jedes Artikels
#    - Alle enthaltenen Zahlen (als Liste)
#    - Die 5 haeufigsten Woerter (min. 4 Zeichen)
# 3. Einen formatierten Report in `ausgabe_pfad` schreibt:
# ```
# === Zeitungsanalyse: mittelbach_aktuell.txt ===
#
# Umfang:
#   Zeichen : 2969
#   Woerter : 412
#   Zeilen  : 66
#
# Artikel (5):
#   1. STADTRAT BESCHLIESST NEUE FAHRRADWEGE
#   2. FEUERWEHR RETTET KATZE AUS 12 METER HOHER EICHE
#   ...
#
# Zahlen im Text: [3, 12, 15, 22, ...]
#
# Haeufigste Woerter:
#   mittelbach (4x)
#   ...
# ```
# 4. Den Report auch auf der Konsole ausgeben.
# 5. Fehlerbehandlung: Datei nicht gefunden -> sinnvolle Meldung nach `sys.stderr`.
#
# Teste: `analysiere_zeitung('mittelbach_aktuell.txt', 'report.txt')`
#
# Dokumentation: https://docs.python.org/3/library/functions.html#open
