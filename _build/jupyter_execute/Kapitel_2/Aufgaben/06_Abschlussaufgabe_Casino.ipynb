# %% [markdown]
# # Abschlussaufgabe Casino

# %% [markdown]
# <div style="display:flex;justify-content:space-between;align-items:center;background:#0d0d0f;border:1px solid #1e1e24;border-left:4px solid #4fc3f7;border-radius:6px;padding:clamp(1rem,2.5vw,1.8rem) clamp(1.2rem,3vw,2.4rem);margin-bottom:2rem;position:relative;overflow:hidden;box-shadow:0 4px 32px rgba(0,0,0,0.5);font-family:'Segoe UI',sans-serif;">
# <div style="position:absolute;top:0;left:0;right:0;bottom:0;background:radial-gradient(ellipse at 0% 50%,rgba(79,195,247,0.07) 0%,transparent 60%);pointer-events:none;"></div>
# <div style="display:flex;flex-direction:column;gap:0.3rem;">
# <p style="font-size:clamp(1.3rem,3.5vw,2.4rem);color:#f0f0f5;margin:0;line-height:1.1;font-weight:700;letter-spacing:-0.01em;">Practice Sheet: Casino-Bot</p>
# <p style="font-size:clamp(0.75rem,1.6vw,1rem);color:#7a7a90;margin:0;letter-spacing:0.04em;font-weight:300;">Development Expert Python &nbsp;|&nbsp; PCAP Section 1: Module &amp; Packages &nbsp;|&nbsp; Practice 01</p>
# </div>
# </div>

# %% [markdown]
# <div style="background:#080f17;border:1px solid #1a2e42;border-radius:8px;padding:1.4rem 1.8rem;margin-bottom:1.5rem;font-family:'Segoe UI',sans-serif;">
# <p style="font-size:1.05rem;font-weight:700;color:#4fc3f7;margin:0 0 0.8rem 0;letter-spacing:0.05em;text-transform:uppercase;">Briefing</p>
# <p style="color:#c5cae9;margin:0 0 0.7rem 0;line-height:1.7;font-size:0.95rem;">Du bist Junior-Developer beim aufstrebenden Online-Casino <strong style="color:#f0f0f5;">"PyBet GmbH"</strong>. Dein Chef, der legendäre Willi Vollrisiko, hat gerade erfahren, dass euer Haupt-Bot abgestürzt ist, zehn Minuten vor dem großen Poker-Turnier.</p>
# <p style="color:#c5cae9;margin:0 0 0.7rem 0;line-height:1.7;font-size:0.95rem;">Willi ruft an: <em style="color:#4fc3f7;">"Ich brauch den Bot in einer Stunde. Ich weiß nicht was ein Import ist. Ich weiß nicht was ein Modul ist. Ich weiß nur: wenn das nicht läuft, machen wir beide heute Abend Überstunden."</em></p>
# <p style="color:#c5cae9;margin:0;line-height:1.7;font-size:0.95rem;">Deine Mission: Den Casino-Bot neu aufbauen mit <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.4em;border-radius:3px;">random</code>, <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.4em;border-radius:3px;">math</code> und <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.4em;border-radius:3px;">platform</code>. Willi schaut zu.</p>
# </div>
#
# ---
#
# **Abgedeckter PCAP-Stoff:** `1.1` Import-Varianten · `1.2` math-Modul · `1.3` random-Modul · `1.4` platform-Modul · `1.5` Eigene Module & Packages
#
# **Aufgabentypen:** Vorhersage, Fehler finden, Lückentext, Code-Snippets, Szenario-Mission

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">PCAP 1.1 · 1.3</span>
# Checkpoint 1: Vorhersage-Aufgaben
# </span>
# </div>
#
# **Regel:** Den Code nicht ausführen. Ausgabe direkt als Kommentar in die Code-Zelle schreiben.
#
# **Aufgabe 1.1 - Was gibt das aus?**
#
# ```python
# import random as r
#
# r.seed(42)
# x = r.randint(1, 6)
# y = r.randint(1, 6)
# print(x, y, x + y)
# ```
#
# Deine Antwort (als Kommentar im Code unten):

# %%
# Aufgabe 1.1
# Ausgabe: ???
# Begründung:

# %% [markdown]
# **Aufgabe 1.2 - Was gibt das aus?**
#
# ```python
# from math import floor, ceil
#
# bet = 7.3
# print(floor(bet))
# print(ceil(bet))
# print(floor(-bet))
# print(ceil(-bet))
# ```
#
# Deine Antwort:

# %%
# Aufgabe 1.2
# floor(7.3)  → 
# ceil(7.3)   → 
# floor(-7.3) → 
# ceil(-7.3)  →

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">PCAP 1.1 · 1.2 · 1.3</span>
# Checkpoint 2: Fehler finden
# </span>
# </div>
#
# **Aufgabe:** Im folgenden Code stecken 4 Fehler. Alle finden, korrigieren und die bereinigte Version in die Code-Zelle schreiben.
#
# ```python
# # Willis erster Versuch
#
# import Random                          # Fehler ?
# from math imports sqrt, factorial      # Fehler ?
#
# random.seed(0)
# wuerfel = random.randInt(1, 6)         # Fehler ?
#
# gewinn = sqrt(wuerfel * 100)
# print(f"Gewinn: {math.floor(gewinn)}") # Fehler ?
# ```

# %%
# Deine korrigierte Version:



# Fehler 1: 
# Fehler 2: 
# Fehler 3: 
# Fehler 4:

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">PCAP 1.1 · 1.3 · 1.4</span>
# Checkpoint 3: Lückentext
# </span>
# </div>
#
# Jede `______` steht für genau einen Bezeichner oder ein Schlüsselwort.
#
# ```python
# ______ random                          # (1) Ganzes Modul importieren
# from math ______ ceil, floor           # (2) Gezielter Import
# import platform ______ plt             # (3) Alias vergeben
#
# # Systeminfo ausgeben
# print(plt.______ ())                   # (4) Betriebssystem-Name
# print(plt.python_______())             # (5) Python-Version als Tuple
#
# # Zufallswerte
# karten = ['As', '7', 'Bube', 'Dame', 'König']
# hand = random.______(karten, 2)        # (6) 2 Karten ohne Zurücklegen ziehen
# wert = random.______()                 # (7) Float zwischen 0.0 und 1.0
#
# # Mathematik
# einsatz = 99.9
# rounded = ______(einsatz)              # (8) Aufrunden (ohne math.)
# ```

# %%
# Deine Antworten:
# (1) ______
# (2) ______
# (3) ______
# (4) ______
# (5) _____________
# (6) ______
# (7) ______
# (8) ______

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">PCAP 1.1 · 1.2 · 1.3 · 1.4</span>
# Code-Snippets: Einzelfunktionen implementieren
# </span>
# </div>
#
# Jede Funktion nach der Beschreibung implementieren. Die assert-Blöcke am Ende jeder Zelle zeigen, ob die Lösung korrekt ist.
#
# ---
#
# <div style="background:#0d1f2d;border-left:3px solid #1e4d6b;border-radius:3px;padding:0.55em 1em;margin:1.5rem 0 0.9rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(0.9rem,1.8vw,1.05rem);font-weight:600;color:#c5cae9;letter-spacing:-0.005em;">
# <span style="font-size:0.6rem;letter-spacing:0.1em;text-transform:uppercase;color:#80cbc4;background:rgba(128,203,196,0.1);border:1px solid rgba(128,203,196,0.25);border-radius:3px;padding:0.15em 0.5em;margin-right:0.65em;vertical-align:middle;white-space:nowrap;">Snippet 1</span>
# wuerfel_wurf(): Würfelwurf mit konfigurierbaren Seiten
# </span>
# </div>
#
# Schreibe eine Funktion `wuerfel_wurf(seiten=6)` die:
# - Eine zufällige Ganzzahl zwischen `1` und `seiten` (inklusiv) zurückgibt
# - Das `random`-Modul verwendet
# - Bei `seiten < 2` einen `ValueError` mit der Nachricht `"Würfel braucht mindestens 2 Seiten"` wirft

# %%
import random

def wuerfel_wurf(seiten=6):
    # Deine Implementierung:
    pass


# --- Testaufrufe (sollen ohne Fehler laufen) ---
random.seed(99)
ergebnis = wuerfel_wurf()
assert 1 <= ergebnis <= 6, f"Erwartet: 1-6, erhalten: {ergebnis}"

ergebnis20 = wuerfel_wurf(20)
assert 1 <= ergebnis20 <= 20, f"Erwartet: 1-20, erhalten: {ergebnis20}"

try:
    wuerfel_wurf(1)
    assert False, "ValueError wurde nicht geworfen!"
except ValueError as e:
    assert "mindestens 2" in str(e)

print("Snippet 1: alle Tests bestanden")

# %% [markdown]
# <div style="background:#0d1f2d;border-left:3px solid #1e4d6b;border-radius:3px;padding:0.55em 1em;margin:1.5rem 0 0.9rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(0.9rem,1.8vw,1.05rem);font-weight:600;color:#c5cae9;letter-spacing:-0.005em;">
# <span style="font-size:0.6rem;letter-spacing:0.1em;text-transform:uppercase;color:#80cbc4;background:rgba(128,203,196,0.1);border:1px solid rgba(128,203,196,0.25);border-radius:3px;padding:0.15em 0.5em;margin-right:0.65em;vertical-align:middle;white-space:nowrap;">Snippet 2</span>
# berechne_gewinn(): Auszahlung mit mathematischer Rundung
# </span>
# </div>
#
# Schreibe `berechne_gewinn(einsatz, multiplikator)` die:
# - Den Brutto-Gewinn als `einsatz * multiplikator` berechnet
# - Nur den ganzzahligen Teil (abrunden) als `int` zurückgibt
# - `math.floor()` **nicht** `int()` oder `round()` verwenden
# - Hinweis: Was ist der Unterschied zwischen `floor()` und `int()` bei negativen Zahlen?

# %%
from math import floor

def berechne_gewinn(einsatz, multiplikator):
    # Deine Implementierung:
    pass


# --- Testaufrufe ---
assert berechne_gewinn(10, 2.5) == 25
assert berechne_gewinn(7, 1.3) == 9
assert berechne_gewinn(10, -1.5) == -15   # Achtung: floor vs int!
assert isinstance(berechne_gewinn(5, 2), int)

print("Snippet 2: alle Tests bestanden")

# %% [markdown]
# <div style="background:#0d1f2d;border-left:3px solid #1e4d6b;border-radius:3px;padding:0.55em 1em;margin:1.5rem 0 0.9rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(0.9rem,1.8vw,1.05rem);font-weight:600;color:#c5cae9;letter-spacing:-0.005em;">
# <span style="font-size:0.6rem;letter-spacing:0.1em;text-transform:uppercase;color:#80cbc4;background:rgba(128,203,196,0.1);border:1px solid rgba(128,203,196,0.25);border-radius:3px;padding:0.15em 0.5em;margin-right:0.65em;vertical-align:middle;white-space:nowrap;">Snippet 3</span>
# karten_ziehen(): Hand aus einem Kartenspiel
# </span>
# </div>
#
# Schreibe `karten_ziehen(deck, anzahl)` die:
# - `anzahl` Karten **ohne Zurücklegen** aus `deck` zieht und als Liste zurückgibt
# - Die Originalreihenfolge in `deck` **nicht** verändert
# - `random.sample()` verwendet (nicht `random.choices()`!)
# - Bei `anzahl > len(deck)` einen `ValueError` wirft
#
# >  PCAP-Falle: Was ist der Unterschied zwischen `sample()` und `choices()`?

# %%
import random

KARTENSPIEL = ['2', '3', '4', '5', '6', '7', '8', '9', '10',
               'Bube', 'Dame', 'König', 'As'] * 4  # 52 Karten

def karten_ziehen(deck, anzahl):
    # Deine Implementierung:
    pass


# --- Testaufrufe ---
random.seed(7)
hand = karten_ziehen(KARTENSPIEL, 5)
assert len(hand) == 5, f"Erwartet 5 Karten, erhalten: {len(hand)}"
assert len(KARTENSPIEL) == 52, "Das Originaldeck wurde verändert!"

try:
    karten_ziehen(['A', 'B'], 10)
    assert False, "ValueError wurde nicht geworfen!"
except ValueError:
    pass

print("Snippet 3: alle Tests bestanden")
print(f"Deine Hand: {hand}")

# %% [markdown]
# <div style="background:#0d1f2d;border-left:3px solid #1e4d6b;border-radius:3px;padding:0.55em 1em;margin:1.5rem 0 0.9rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(0.9rem,1.8vw,1.05rem);font-weight:600;color:#c5cae9;letter-spacing:-0.005em;">
# <span style="font-size:0.6rem;letter-spacing:0.1em;text-transform:uppercase;color:#80cbc4;background:rgba(128,203,196,0.1);border:1px solid rgba(128,203,196,0.25);border-radius:3px;padding:0.15em 0.5em;margin-right:0.65em;vertical-align:middle;white-space:nowrap;">Snippet 4</span>
# system_check(): Plattform-Report
# </span>
# </div>
#
# Schreibe `system_check()` die einen Dictionary zurückgibt mit:
# - `"os"` → Betriebssystem-Name (z.B. `"Windows"`, `"Linux"`)
# - `"python"` → Python-Version als String (z.B. `"3.11.2"`)
# - `"maschine"` → Prozessorarchitektur (z.B. `"AMD64"`)
# - `"python_tuple"` → Python-Version als Tuple von 3 Strings
#
# Verwende **ausschließlich** das `platform`-Modul (keine anderen Importe).

# %%
import platform

def system_check():
    # Deine Implementierung:
    pass


# --- Testaufrufe ---
info = system_check()

assert isinstance(info, dict), "Rückgabe muss ein Dictionary sein"
assert "os" in info
assert "python" in info
assert "maschine" in info
assert "python_tuple" in info
assert isinstance(info["python_tuple"], tuple), "python_tuple muss ein Tuple sein"
assert len(info["python_tuple"]) == 3, "Tuple muss 3 Einträge haben"
assert isinstance(info["python_tuple"][0], str), "Tuple-Einträge müssen Strings sein"

print("Snippet 4: alle Tests bestanden")
for key, val in info.items():
    print(f"  {key}: {val}")

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">PCAP 1.1 · 1.2 · 1.3 · 1.4 · 1.5</span>
# Szenario-Mission: Der Casino-Bot
# </span>
# </div>
#
# <div style="background:#080f17;border:1px solid #1a2e42;border-radius:8px;padding:1.2rem 1.6rem;margin-bottom:1.5rem;font-family:'Segoe UI',sans-serif;">
# <p style="color:#4fc3f7;font-weight:700;margin:0 0 0.6rem 0;font-size:0.9rem;text-transform:uppercase;letter-spacing:0.05em;">Aufgabenstellung</p>
# <p style="color:#c5cae9;margin:0 0 0.6rem 0;line-height:1.7;font-size:0.92rem;">Der Bot muss folgendes können:</p>
# <ul style="color:#c5cae9;margin:0;padding-left:1.4rem;line-height:2;font-size:0.92rem;">
# <li>Spielersitzungen mit Name und Startguthaben verwalten</li>
# <li>Würfelspiel: Spieler würfelt, bei 6 → Einsatz x 5, sonst verloren</li>
# <li>Kartenspiel: 5 Karten ziehen, Preis hängt von Anzahl Asse ab</li>
# <li>System-Report ausgeben (Plattform, Python-Version)</li>
# <li>Alle Gewinne mathematisch korrekt runden</li>
# </ul>
# </div>
#
# Deine Aufgabe: Fülle alle `# TODO`-Stellen aus. Verändere nichts außerhalb der TODOs.
#
# Die `# TESTBLOCK`-Zelle am Ende darf **nicht** verändert werden. Sie zeigt an, ob alles klappt.

# %%
# ============================================================
#  casino_bot.py  |  PyBet GmbH  |  Willi wartet
# ============================================================

# TODO 1: Importiere random (ganzes Modul)
# TODO 2: Importiere floor und sqrt aus math
# TODO 3: Importiere platform mit Alias 'plt'


# ── Konstanten ──────────────────────────────────────────────
DECK = ['2', '3', '4', '5', '6', '7', '8', '9', '10',
        'Bube', 'Dame', 'König', 'As'] * 4

AUSZAHLUNGSTABELLE = {
    0: 0,    # kein As → kein Gewinn
    1: 5,    # 1 As    → Einsatz x5
    2: 15,   # 2 Asse  → Einsatz x15
    3: 50,   # 3 Asse  → Einsatz x50
    4: 200,  # 4 Asse  → Jackpot!
}


# ── Spieler-Session ─────────────────────────────────────────
class CasinoSession:
    """
    Verwaltet eine Spielersitzung beim Casino-Bot.
    """

    def __init__(self, spieler_name, startguthaben):
        self.name = spieler_name
        # TODO 4: Speichere startguthaben als self.guthaben
        # TODO 5: Erstelle self.verlauf als leere Liste
        pass

    def _buche(self, betrag, beschreibung):
        """Intern: Buche einen Betrag (positiv = Gewinn, negativ = Verlust)."""
        # TODO 6: Addiere betrag zu self.guthaben
        # TODO 7: Hänge den String f"{beschreibung}: {betrag:+}" an self.verlauf an
        pass

    # ── Würfelspiel ─────────────────────────────────────────
    def wuerfel_spiel(self, einsatz):
        """
        Würfelt mit einem 6-seitigen Würfel.
        Bei einer 6: Gewinn = floor(einsatz * 5)
        Sonst: Verlust = einsatz
        Gibt (wurf, gewinn_oder_verlust) zurück.
        """
        # TODO 8: Würfle eine Zahl zwischen 1 und 6 mit random.randint
        wurf = None  # ersetzen

        if wurf == 6:
            # TODO 9: Berechne gewinn als floor(einsatz * 5), buche positiv
            pass
        else:
            # TODO 10: Buche einsatz als negativen Verlust
            pass

        # TODO 11: Gib (wurf, gewinn_oder_verlust) zurück
        return None, None  # ersetzen

    # ── Kartenspiel ─────────────────────────────────────────
    def karten_spiel(self, einsatz):
        """
        Zieht 5 Karten aus DECK.
        Gewinn hängt von Anzahl Asse in der Hand ab (siehe AUSZAHLUNGSTABELLE).
        Gibt (hand, anzahl_asse, gewinn_oder_verlust) zurück.
        """
        # TODO 12: Ziehe 5 Karten mit random.sample aus DECK
        hand = None  # ersetzen

        # TODO 13: Zähle wie viele 'As' in der hand sind
        anzahl_asse = None  # ersetzen

        multiplikator = AUSZAHLUNGSTABELLE[anzahl_asse]

        if multiplikator > 0:
            # TODO 14: Berechne gewinn als floor(einsatz * multiplikator), buche positiv
            pass
        else:
            # TODO 15: Buche einsatz als negativen Verlust
            pass

        # TODO 16: Gib (hand, anzahl_asse, gewinn_oder_verlust) zurück
        return None, None, None  # ersetzen

    # ── System-Report ────────────────────────────────────────
    def system_report(self):
        """
        Gibt einen formatierten Report als String zurück.
        Enthält: Spielername, aktuelles Guthaben, OS, Python-Version.
        """
        # TODO 17: Hole Betriebssystem mit plt.system()
        os_name = None  # ersetzen

        # TODO 18: Hole Python-Version-Tuple mit plt.python_version_tuple()
        py_version = None  # ersetzen

        # TODO 19: Formatiere py_version als "Major.Minor.Patch" String
        py_str = None  # ersetzen

        report = (
            f"=== PyBet System Report ===\n"
            f"Spieler  : {self.name}\n"
            f"Guthaben : {self.guthaben} €\n"
            f"System   : {os_name}\n"
            f"Python   : {py_str}\n"
        )
        return report

    def __str__(self):
        return f"CasinoSession({self.name}, Guthaben={self.guthaben})"

# %%
# ============================================================
#  TESTBLOCK - nicht verändern!
# ============================================================

import math  # nur für den Test

random.seed(2024)

# Test 1: Session erstellen
session = CasinoSession("Willi", 500)
assert session.name == "Willi"
assert session.guthaben == 500
assert isinstance(session.verlauf, list)
print("Test 1: Session erstellt")

# Test 2: __str__
assert "Willi" in str(session)
assert "500" in str(session)
print("Test 2: __str__ funktioniert")

# Test 3: Würfelspiel
guthaben_vorher = session.guthaben
wurf, ergebnis = session.wuerfel_spiel(50)
assert isinstance(wurf, int) and 1 <= wurf <= 6
assert len(session.verlauf) == 1
if wurf == 6:
    assert ergebnis == math.floor(50 * 5)
    assert session.guthaben == guthaben_vorher + ergebnis
else:
    assert ergebnis == -50
    assert session.guthaben == guthaben_vorher - 50
print(f"Test 3: Würfelspiel (Wurf: {wurf}, Ergebnis: {ergebnis:+})")

# Test 4: Kartenspiel
hand, asse, ergebnis = session.karten_spiel(100)
assert isinstance(hand, list) and len(hand) == 5
assert isinstance(asse, int) and 0 <= asse <= 4
assert len(session.verlauf) == 2
print(f"Test 4: Kartenspiel (Hand: {hand}, Asse: {asse}, Ergebnis: {ergebnis:+})")

# Test 5: System Report
report = session.system_report()
assert isinstance(report, str)
assert "Willi" in report
assert "System" in report
assert "Python" in report
print("Test 5: System Report")
print()
print(report)

print("Alle Tests bestanden.")

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">PCAP 1.5</span>
# Bonus: Eigenes Package
# </span>
# </div>
#
# Willi möchte den Casino-Bot als **eigenständiges Package** veröffentlichen. Erstelle folgende Dateistruktur (nur als Kommentar, kein echtes Filesystem):
#
# ```
# pybet/
# ├── __init__.py
# ├── session.py       ← CasinoSession-Klasse
# ├── spiele.py        ← wuerfel_spiel, karten_spiel als freie Funktionen
# └── utils.py         ← system_check, berechne_gewinn
# ```
#
# **Aufgabe:**
# 1. Was muss in `__init__.py` stehen, damit `from pybet import CasinoSession` funktioniert?
# 2. Schreibe den Inhalt von `__init__.py` in die Code-Zelle unten
# 3. Wie würde ein anderes Skript `casino_main.py` das Package importieren? Schreibe 3 verschiedene gültige Import-Varianten (PCAP 1.1)

# %%
# Aufgabe 1 + 2: Inhalt von pybet/__init__.py


# Aufgabe 3: 3 Import-Varianten in casino_main.py
# Variante A:

# Variante B:

# Variante C:

# %% [markdown]
# <div style="background:#080f17;border:1px solid #1a2e42;border-radius:8px;padding:1.2rem 1.6rem;margin-top:2.5rem;font-family:'Segoe UI',sans-serif;">
# <p style="color:#4fc3f7;font-weight:700;margin:0 0 0.8rem 0;font-size:0.85rem;text-transform:uppercase;letter-spacing:0.06em;">PCAP-Prüfungshinweise: Section 1</p>
# <ul style="color:#c5cae9;margin:0;padding-left:1.4rem;line-height:2;font-size:0.88rem;">
# <li><strong style="color:#f0f0f5;">import as</strong> macht den Originalnamen ungültig. <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.35em;border-radius:3px;">import platform as plt</code> → <code style="background:#0b1929;color:#ef9a9a;padding:0.1em 0.35em;border-radius:3px;">platform.system()</code> ist dann ungültig.</li>
# <li><strong style="color:#f0f0f5;">floor() vs int()</strong> bei negativen Zahlen: <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.35em;border-radius:3px;">floor(-7.3) = -8</code>, aber <code style="background:#0b1929;color:#4fc3f7;padding:0.1em 0.35em;border-radius:3px;">int(-7.3) = -7</code></li>
# <li><strong style="color:#f0f0f5;">sample() vs choices()</strong>: sample = ohne Zurücklegen, choices = mit Zurücklegen</li>
# <li><strong style="color:#f0f0f5;">python_version_tuple()</strong> gibt immer Strings zurück, keine ints.</li>
# <li><strong style="color:#f0f0f5;">dir(modul)</strong> gibt eine Liste von Strings zurück, alphabetisch sortiert</li>
# <li><strong style="color:#f0f0f5;">seed()</strong> macht Zufallssequenzen reproduzierbar (wichtig für Tests)</li>
# </ul>
# </div>
