# %% [markdown]
# # Aufgaben: Pcap list comprehension

# %% [markdown]
# **Frage 1**
#
# Was ist die Ausgabe des folgenden Codes?
# ```python
# words = ["Anna", "Otto", "Eva", "Ulf"]
# result = filter(lambda w: w[0].lower() == w[-1].lower(), words)
# for w in result:
#     print(w[1], end="")
# ```
# A) tn
#
# B) nv
#
# C) vn
#
# D) nt

# %%
words = ["Anna", "Otto", "Eva", "Ulf"]
result = filter(lambda w: w[0].lower() == w[-1].lower(), words)
for w in result:
    print(w[1], end="")

# %% [markdown]
# **Frage 2**
#
# Was ist die Ausgabe des folgenden Codes?
# ```python
# lst = [2, 4, 6, 8]
# print(list(map(lambda x: x // 2, lst))[::2])
# ```
# A) [1, 3]
#
# B) [1, 2, 3, 4]
#
# C) [1, 4]
#
# D) [1, 2]

# %% [markdown]
# **Frage 3**
#
# Was ist das Ergebnis von folgendem Code?
# ```python
# v = [0, 1, 2]
# def f(a, b, func):
#     return func(a, b)
# print(f(0, 2, lambda x, y: v[x:y]))
# ```
# A) [0, 1]
#
# B) [1, 2]
#
# C) [0, 2]
#
# D) [0, 1, 2]

# %% [markdown]
# **Frage 4**
#
# Was ist das Ergebnis von folgendem Code?
# ```python
# f = lambda x: x if x > 10 else x + 10
# print(f(5))
# ```
# A) 5
#
# B) 10
#
# C) 15
#
# D) Error

# %% [markdown]
# **Frage 5**
#
# Welche Ausgabe erzeugt dieser Code?
# ```python
# nums = [1, 2, 3, 4, 5]
# f = list(filter(lambda x: x % 2 == 0, nums))
# print(f[0])
# ```
# A) 2
#
# B) 1
#
# C) 0
#
# D) 4

# %% [markdown]
# **Frage 6**
#
# Was wird ausgegeben, wenn der folgende Code ausgeführt wird?
# ```python
# data = ["a1", "b2", "c3", "d4"]
# result = list(map(lambda x: x[0].upper() + x[1], data))
# print("".join(result))
# ```
# A) A1B2C3D4
#
# B) a1b2c3d4
#
# C) A1b2c3d4
#
# D) a1B2c3D4

# %% [markdown]
# **Frage 7**
#
# Was passiert, wenn dieser Code ausgeführt wird?
# ```python
# funcs = []
# for i in range(3):
#     funcs.append(lambda: i)
#
# results = [f() for f in funcs]
# print(results)
# ```
# A) [0, 1, 2]
#
# B) [2, 2, 2]
#
# C) [3, 3, 3]
#
# D) SyntaxError

# %% [markdown]
# **Frage 8**
#
# Was ist die Ausgabe des folgenden Codes?
# ```python
# def make():
#     return [lambda x, n=n: x + n for n in range(3)]
#
# funcs = make()
# print([f(10) for f in funcs])
# ```
# A) [10, 10, 10]
#
# B) [13, 13, 13]
#
# C) [10, 11, 12]
#
# D) [13, 12, 11]

# %% [markdown]
# **Frage 9**
#
# Was passiert, wenn der folgende Code ausgeführt wird?
# ```python
# lst = [0, 1, 2, 3]
# result = [x for x in lst if x]
# print(result)
# ```
# A) [0, 1, 2, 3]
#
# B) [1, 2, 3]
#
# C) [0]
#
# D) []

# %%
lst = [0, 1, 2, 3]
result = [x for x in lst if x]
print(result)

# %% [markdown]
# **Frage 10**
#
# Was ist die Ausgabe des folgenden Codes?
# ```python
# print([x * 2 for x in range(5) if x % 2])
# ```
# A) [0, 2, 4, 6, 8]
#
# B) [2, 6]
#
# C) [0, 4, 8]
#
# D) [2, 6, 10]

# %%
print([x * 2 for x in range(5) if x % 2])

# %% [markdown]
# **Frage 11**
#
# Was ist das Ergebnis von folgendem Code?
# ```python
# print([x + y for x in "ab" for y in "cd" if x != y])
# ```
# A) ['ad', 'bc']
#
# B) ['ac', 'ad', 'bd']
#
# C) ['ac', 'bd']
#
# D) ['ac', 'ad', 'bc', 'bd']

# %% [markdown]
# **Frage 12**
#
# Welche Ausgabe erzeugt dieser Code?
# ```python
# words = ["zero", "one", "two", "three"]
# result = filter(lambda x: len(x) == 3 or x[0] == x[-1], words)
# for w in result:
#     print(w[-2], end="")
# ```
# A) no
#
# B) nw
#
# C) wt
#
# D) et

# %% [markdown]
# **Frage 13**
#
# Was wird ausgegeben, wenn der folgende Code ausgeführt wird?
# ```python
# items = ["yes", "no", "ok"]
# out = map(lambda x: x[0].upper() if len(x) == 2 else x[-1], items)
# print("".join(out))
# ```
# A) soO
#
# B) sNO
#
# C) sOK
#
# D) sok

# %% [markdown]
# **Frage 14**
#
# Was ist die Ausgabe des folgenden Codes?
# ```python
# data = ["123", "abc", "4d5"]
# res = map(lambda s: s[1] if s[1].isdigit() else s[2], data)
# for ch in res:
#     print(ch, end="")
# ```
# A) 2bc
#
# B) 2b5
#
# C) 2cb
#
# D) 2c5

# %% [markdown]
# **Frage 15** (Sorry)
#
# Was wird ausgegeben, wenn der folgende Code ausgeführt wird?
# ```python
# words = ["Otto", "Anna", "Kayak", "Radar", "Python", "Bob", "Eve", "Level"]
#
# step1 = filter(lambda w: w.lower() == w[::-1].lower(), words)
#
# step2 = map(lambda w: w[1].upper() + (w[-2] if len(w) >= 4 else "_"), step1)
#
# step3 = [x for x in step2 if x[1].islower() or x[0] in "AEIOU"]
#
# print("".join(step3))
# ```
#
# A) TNnKDAE
#
# B) TN_KDE
#
# C) Tt_nNaAoO
#
# D) TtNnAaAaO_Ee

# %%
# PCAP Aufgabe 1

vect = ["alpha", "bravo", "charlie"]
new_vect = filter(lambda s: s[-1].upper() in ["A", "O"], vect)
for x in new_vect:
    print(x[1], end="")

# %%
# PCAP Aufgabe 2
v = [1, 2, 3]

def g(a, b, m):
    return m(a, b)

print(g(1, 1, lambda x, y: v[x:y+1]))

# %%
# PCAP Aufgabe 3
def f(a, b):
    return a(b)

print(f(lambda x: x and True, 1 > 0))
