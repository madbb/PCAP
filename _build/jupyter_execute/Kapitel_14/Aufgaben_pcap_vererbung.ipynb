# %% [markdown]
# # Aufgaben: Pcap vererbung

# %% [markdown]
# **Frage 1 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Tier:
#     def stimme(self):
#         print("Tierstimme")
#
# class Hund(Tier):
#     pass
#
# h = Hund()
# h.stimme()
# ```
#
# A) `Tierstimme`
# B) `Hundestimme`
# C) `AttributeError`
# D) `None`

# %% [markdown]
# **Frage 2 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Fahrzeug:
#     def __init__(self):
#         self.hat_raeder = True
#
# class Auto(Fahrzeug):
#     def __init__(self):
#         self.hat_motor = True
#
# a = Auto()
# print(a.hat_raeder)
# ```
#
# A) `True`
# B) `False`
# C) `AttributeError`
# D) Es wird eine leere Zeile ausgegeben

# %%
class Fahrzeug:
    def __init__(self):
        self.hat_raeder = True

class Auto(Fahrzeug):
    def __init__(self):
        self.hat_motor = True

a = Auto()
print(a.hat_raeder)

# %% [markdown]
# **Frage 3 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A:
#     def methode(self):
#         print('A')
#
# class B(A):
#     def methode(self):
#         print('B')
#
# b = B()
# b.methode()
# ```
#
# A) `A`
# B) `B`
# C) `A` gefolgt von `B`
# D) `B` gefolgt von `A`

# %%
class A:
    def methode(self):
        print('A')

class B(A):
    def methode(self):
        print('B')

b = B()
b.methode()
# Out:
# B

# %% [markdown]
# **Frage 4 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Motor:
#     def start(self):
#         return "Motor gestartet"
#
# class Karosserie:
#     def polieren(self):
#         return "Karosserie poliert"
#
# class Auto(Motor, Karosserie):
#     pass
#
# mein_auto = Auto()
# print(mein_auto.polieren())
# ```
#
# A) `Motor gestartet`
# B) `Karosserie poliert`
# C) `TypeError`
# <br>D) Es wird eine leere Zeile ausgegeben

# %% [markdown]
# **Frage 5 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Links:
#     v = 'L'
#
# class Rechts:
#     v = 'R'
#
# class Kind(Links, Rechts):
#     pass
#
# print(Kind.v)
# ```
#
# A) `L`
# B) `R`
# C) `AttributeError`
# <br>D) `TypeError`

# %% [markdown]
# **Frage 6 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A: pass
# class B(A): pass
# class C: pass
#
# b_instanz = B()
# print(isinstance(b_instanz, C))
# ```
#
# A) `True`
# B) `False`
# C) `None`
# D) `TypeError` - MRO Fehler

# %%
class A: pass
class B(A): pass
class C: pass

b_instanz = B()
print(isinstance(b_instanz, C))
# Out:
# False

# %% [markdown]
# **Frage 7 von 25**
#
# Welche der folgenden Aussagen gibt `True` aus?
#
# ```python
# class Tier: pass
# class Saeugetier(Tier): pass
# class Hund(Saeugetier): pass
#
# h = Hund()
# ```
#
# A) `print(isinstance(h, Tier) and not isinstance(Saeugetier(), Hund))`
# B) `print(type(h) is Tier)`
# C) `print(isinstance(Tier(), Hund))`
# D) `print(type(h) is Saeugetier)`

# %%
class Tier: pass
class Saeugetier(Tier): pass
class Hund(Saeugetier): pass

h = Hund()


print(isinstance(h, Tier) and not isinstance(Saeugetier(), Hund))
print(type(h) is Tier)
print(isinstance(Tier(), Hund))
print(type(h) is Saeugetier)
# Out:
# True
# False
# False
# False

# %% [markdown]
# **Frage 8 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A: pass
# b = A()
# a = b
#
# print(a is not b)
# ```
#
# A) `True`
# B) `False`
# C) `None`
# D) `SyntaxError`

# %% [markdown]
# **Frage 9 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# liste1 = [1, 2]
# liste2 = [1, 2]
#
# print(liste1 is liste2)
# ```
#
# A) `True`
# B) `False`
# C) `1`
# D) `None`

# %% [markdown]
# **Frage 10 von 25**
#
# Das Prinzip, das es einer einzigen Funktion oder Methode erlaubt, mit Objekten unterschiedlicher Klassen zu arbeiten, solange diese eine gemeinsame Schnittstelle (z.B. den gleichen Methodennamen) haben, nennt man:
#
# A) Vererbung
# B) Kapselung
# C) Polymorphismus
# D) Abstraktion

# %% [markdown]
# **Frage 11 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Ente:
#     def laut(self):
#         print("Quak")
#
# class Person:
#     def laut(self):
#         print("Hallo")
#
# def mache_laut(ding):
#     ding.laut()
#
# ente = Ente()
# person = Person()
# mache_laut(person)
# ```
#
# A) `Quak`
# B) `Hallo`
# C) `TypeError` - MRO Fehler
# D) `None`

# %% [markdown]
# **Frage 12 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A:
#     def __str__(self):
#         return "Klasse A"
#
# obj = A()
# print(obj)
# ```
#
# A) `TypeError`
# B) Die Speicheradresse des Objekts
# C) `Klasse A`
# D) `<__main__.A object>`

# %% [markdown]
# **Frage 13 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Basis:
#     def __str__(self):
#         return "Basis"
#
# class Abgeleitet(Basis):
#     pass
#
# obj = Abgeleitet()
# print(obj)
# ```
#
# A) `Abgeleitet`
# B) `Basis`
# C) Die Speicheradresse des Objekts
# D) `ValueError`

# %% [markdown]
# **Frage 14 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A:
#     pass
#
# class B(A):
#     pass
#
# class C(B, A):
#     pass
#
# print(issubclass(C, A))
# ```
# A) `True`
# B) `False`
# C) `None`
# D) `TypeError` - MRO Fehler

# %% [markdown]
# **Frage 15 von 25**
#
# Das "Diamond Problem" in der Programmierung bezieht sich auf eine Mehrdeutigkeit, die entsteht bei:
#
# A) Single Inheritance (Einfachvererbung)
# B) Rekursiven Funktionsaufrufen
# C) Multiple Inheritance (Mehrfachvererbung)
# D) Operatorüberladung

# %% [markdown]
# **Frage 16 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A:
#     def ping(self): print('A')
# class B(A):
#     def ping(self): print('B')
# class C(A):
#     def ping(self): print('C')
# class D(B, C):
#     pass
#
# d = D()
# d.ping()
# ```
#
# A) `A`
# B) `B`
# C) `C`
# D) `TypeError` - MRO Fehler

# %% [markdown]
# **Frage 17 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A:
#     x = 1
# class B(A):
#     pass
# class C(A):
#     x = 3
#
# class D(B, C):
#     pass
#
# print(D.x)
# ```
#
# A) `1`
# B) `2`
# C) `3`
# D) `AttributeError`

# %% [markdown]
# **Frage 18 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Buch:
#     def __init__(self, seiten):
#         self.seiten = seiten
#
#     def __bool__(self):
#         return self.seiten > 0
#
# leeres_buch = Buch(0)
# if not leeres_buch:
#     print("Leer")
# else:
#     print("Voll")
# ```
#
# A) `Leer`
# B) `Voll`
# C) `Leer` gefolgt von `Voll`
# D) `None`

# %% [markdown]
# **Frage 19 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A:
#     def __str__(self):
#         return "a"
#
# class B:
#     def __str__(self):
#         return "b"
#
# class C(A, B):
#     pass
#
# o = C()
# print(o)
# ```
# A) `a`
# B) `b`
# C) `ab`
# D) `ba`

# %% [markdown]
# **Frage 20 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A:
#     def __init__(self):
#         print('A')
# class B(A):
#     def __init__(self):
#         super().__init__()
#         print('B')
#
# b = B()
# ```
#
# A) `B`
# B) `A`
# C) `B` gefolgt von `A`
# D) `A` gefolgt von `B`

# %% [markdown]
# **Frage 21 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Team:
#     def __init__(self):
#         self.mitglieder = []
#
#     def __len__(self):
#         return len(self.mitglieder)
#
# t = Team()
# if t:
#     print("Nicht leer")
# else:
#     print("Leer")
# ```
#
# A) `Nicht leer`
# B) `Leer`
# C) `TypeError`
# <br>D) `0`

# %% [markdown]
# **Frage 22 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class X: pass
# class Y: pass
# class A(X, Y): pass
# class B(Y, X): pass
#
# class Z(A, B):
#     pass
# ```
#
# A) Der Code wird erfolgreich ausgeführt
# B) `SyntaxError`
# C) `NameError`
# D) `TypeError`

# %% [markdown]
# **Frage 23 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class A: pass
# class B(A): pass
#
# a = A()
# b = B()
#
# print(isinstance(a, B), isinstance(b, A))
# ```
#
# A) `True True`
# B) `True False`
# C) `False True`
# D) `False False`

# %% [markdown]
# **Frage 24 von 25**
#
# Welche Methode wird aufgerufen, wenn ein Objekt einer Klasse an die `print()`-Funktion übergeben wird?
#
# A) `__repr__()`
# B) `__print__()`
# C) `__str__()`
# D) `__output__()`

# %% [markdown]
# **Frage 25 von 25**
#
# Was ist das Ergebnis der Ausführung des folgenden Codes?
#
# ```python
# class Eltern:
#     val = 1
# class Kind(Eltern):
#     pass
#
# print(Kind.val)
# Eltern.val = 2
# print(Kind.val)
# ```
#
# A) `1` gefolgt von `1`
# B) `1` gefolgt von `2`
# C) `2` gefolgt von `1`
# D) `2` gefolgt von `2`

# %% [markdown]
# ### Antworten

# %% [markdown]
# 1.  A) `Tierstimme`

# %% [markdown]
# 2.  C) Es wird eine Ausnahme ausgelöst (AttributeError), weil der `__init__` der Basisklasse nicht aufgerufen wird.

# %% [markdown]
# 3.  B) `B`

# %% [markdown]
# 4.  B) `Karosserie poliert`

# %% [markdown]
# 5.  A) `L` (Aufgrund der Method Resolution Order - MRO)

# %% [markdown]
# 6.  B) `False`

# %% [markdown]
# 7.  A) `print(isinstance(h, Tier) and not isinstance(Saeugetier(), Hund))`

# %% [markdown]
# 8.  B) `False`

# %% [markdown]
# 9.  B) `False` (Es sind zwei verschiedene Objekte im Speicher)

# %% [markdown]
# 10. C) Polymorphismus

# %% [markdown]
# 11. B) `Hallo`

# %% [markdown]
# 12. C) `Klasse A`

# %% [markdown]
# 13. B) `Basis` (Die `__str__`-Methode wird geerbt)

# %% [markdown]
# 14. A) `True`

# %% [markdown]
# 15. C) Multiple Inheritance (Mehrfachvererbung)

# %% [markdown]
# 16. B) `B` (Aufgrund der MRO: D -> B -> C -> A)

# %% [markdown]
# 17. C) `3` (Aufgrund der MRO: D -> B -> C -> A. B erbt x von A, aber C überschreibt es. C wird vor A geprüft)

# %% [markdown]
# 18. A) `Leer` (Die `__bool__`-Methode gibt `False` zurück)

# %% [markdown]
# 19. A) `a` (Aufgrund der MRO)

# %% [markdown]
# 20. D) `A` gefolgt von `B`

# %% [markdown]
# 21. B) `Leer` (Wenn `__bool__` nicht da ist, wird `__len__` verwendet. `len()` von 0 ist "falsy")

# %% [markdown]
# 22. D) `TypeError` (Python kann keine konsistente MRO erstellen)

# %% [markdown]
# 23. C) `False True`

# %% [markdown]
# 24. C) `__str__()`

# %% [markdown]
# 25. B) `1` gefolgt von `2` (Die Kind-Klasse greift auf das Attribut der Eltern-Klasse zu)
