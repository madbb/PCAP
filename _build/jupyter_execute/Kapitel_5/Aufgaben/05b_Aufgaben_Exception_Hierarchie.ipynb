# %% [markdown]
# # Aufgaben: Exception Hierarchie

# %% [markdown]
# <div style="display:flex;justify-content:space-between;align-items:center;background:#0d0d0f;border:1px solid #1e1e24;border-left:4px solid #4fc3f7;border-radius:6px;padding:clamp(1rem,2.5vw,1.8rem) clamp(1.2rem,3vw,2.4rem);margin-bottom:2rem;position:relative;overflow:hidden;box-shadow:0 4px 32px rgba(0,0,0,0.5);font-family:'Segoe UI',sans-serif;">
# <div style="position:absolute;top:0;left:0;right:0;bottom:0;background:radial-gradient(ellipse at 0% 50%,rgba(79,195,247,0.07) 0%,transparent 60%);pointer-events:none;"></div>
# <div style="display:flex;flex-direction:column;gap:0.3rem;">
# <p style="font-size:clamp(1.3rem,3.5vw,2.4rem);color:#f0f0f5;margin:0;line-height:1.1;font-weight:700;letter-spacing:-0.01em;">Aufgaben: Exception-Hierarchie und das Exception-Objekt</p>
# <p style="font-size:clamp(0.75rem,1.6vw,1rem);color:#7a7a90;margin:0;letter-spacing:0.04em;font-weight:300;">Development Expert Python &nbsp;|&nbsp; PCAP 2.1 &nbsp;|&nbsp; Kapitel 5: Exceptions &nbsp;|&nbsp; Notebook 05b</p>
# </div>
# </div>

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 1</span>
# Exceptions sind Klassen
# </span>
# </div>

# %% [markdown]
# 1. Gib `type(ValueError)` aus. Was ist das Ergebnis?
# 2. Gib `ValueError.__bases__` aus.
# 3. Gib `ZeroDivisionError.__mro__` aus. Lies die Kette von unten nach oben.
# 4. Pruefe mit `issubclass()`:
#    - Ist `ZeroDivisionError` eine Unterklasse von `ArithmeticError`?
#    - Ist `ZeroDivisionError` eine Unterklasse von `Exception`?
#    - Ist `ValueError` eine Unterklasse von `ArithmeticError`?
# 5. Erklaere als Kommentar: Warum faengt `except Exception` auch `ValueError` ab?

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 2</span>
# Vorhersage: Welcher except-Block greift?
# </span>
# </div>

# %% [markdown]
# Den Code nicht ausfuehren. Ausgabe als Kommentar schreiben, dann pruefen.
#
# **2.1**
# ```python
# try:
#     x = 1 / 0
# except ArithmeticError:
#     print('ArithmeticError')
# except ZeroDivisionError:
#     print('ZeroDivisionError')
# ```
#
# **2.2**
# ```python
# try:
#     x = 1 / 0
# except ZeroDivisionError:
#     print('ZeroDivisionError')
# except ArithmeticError:
#     print('ArithmeticError')
# except Exception:
#     print('Exception')
# ```
#
# **2.3**
# ```python
# try:
#     int('abc')
# except LookupError:
#     print('LookupError')
# except ArithmeticError:
#     print('ArithmeticError')
# except ValueError:
#     print('ValueError')
# except Exception:
#     print('Exception')
# ```
#
# **2.4**
# ```python
# try:
#     x = [][0]
# except LookupError:
#     print('LookupError')
# except IndexError:
#     print('IndexError')
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 3</span>
# except E as e: das Exception-Objekt
# </span>
# </div>

# %% [markdown]
# 1. Fuehre aus und gib folgende Werte des Exception-Objekts aus:
# ```python
# try:
#     int('keine Zahl')
# except ValueError as e:
#     # Gib aus: str(e), type(e), type(e).__name__
#     # Gib aus: e.args, type(e.args)
#     # Gib aus: e.args[0]
# ```
# 2. Teste dasselbe mit `ZeroDivisionError` (durch 0 teilen).
# 3. Schreibe eine Funktion `fehler_info(fn, *args)`,
#    die `fn(*args)` aufruft, jeden `Exception` abfaengt
#    und ein Dictionary `{'typ': ..., 'meldung': ..., 'args': ...}` zurueckgibt.
#    Bei Erfolg: gibt `None` zurueck.
# 4. Teste:
# ```python
# print(fehler_info(int, 'abc'))
# print(fehler_info(lambda: 1/0))
# print(fehler_info(int, '42'))   # kein Fehler -> None
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 4</span>
# args: Aufbau und Zugriff
# </span>
# </div>

# %% [markdown]
# 1. Erstelle Exception-Objekte direkt (ohne `raise`) und untersuche `args`:
# ```python
# e1 = ValueError('eine Meldung')
# e2 = ValueError('erstes', 'zweites', 'drittes')
# e3 = ValueError()
# ```
#    Gib jeweils `e.args`, `len(e.args)` und `str(e)` aus.
# 2. Erklaere als Kommentar:
#    - Was gibt `str(e)` bei einem Element in `args` aus?
#    - Was gibt `str(e)` bei mehreren Elementen aus?
#    - Was gibt `str(e)` bei leerem `args` aus?
# 3. Zeige, dass `args` ein normales Attribut ist das man setzen kann:
# ```python
# e = ValueError('original')
# print(str(e))       # original
# e.args = ('neu',)
# print(str(e))       # neu
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 5</span>
# Vorhersage: args und str(e)
# </span>
# </div>

# %% [markdown]
# Den Code nicht ausfuehren. Ausgabe als Kommentar schreiben, dann pruefen.
#
# **5.1**
# ```python
# try:
#     raise ValueError('Ungueltig')
# except ValueError as e:
#     print(e.args)
#     print(str(e))
#     print(len(e.args))
# ```
#
# **5.2**
# ```python
# try:
#     raise ValueError('Ungueltig', 42, True)
# except ValueError as e:
#     print(e.args)
#     print(str(e))
#     print(e.args[1])
# ```
#
# **5.3**
# ```python
# try:
#     raise ValueError()
# except ValueError as e:
#     print(e.args)
#     print(str(e))
#     print(bool(e.args))
# ```
#
# **5.4**
# ```python
# e = Exception('Start')
# print(str(e))
# e.args = ('Mitte', 'Ende')
# print(str(e))
# e.args = ()
# print(str(e))
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 6</span>
# BaseException vs. Exception
# </span>
# </div>

# %% [markdown]
# 1. Erklaere als Kommentar den Unterschied zwischen `BaseException` und `Exception`.
#    Welche Klassen erben direkt von `BaseException` aber nicht von `Exception`?
# 2. Fuehre aus und erklaere das Ergebnis:
# ```python
# try:
#     raise KeyboardInterrupt
# except Exception:
#     print('Exception gefangen')
# except BaseException:
#     print('BaseException gefangen')
# ```
# 3. Warum sollte man `except BaseException` fast nie verwenden?
#    Erklaere als Kommentar.
# 4. Schreibe eine Funktion `sicher_ausfuehren(fn)`,
#    die `fn()` aufruft und nur `Exception`-Unterklassen abfaengt.
#    `KeyboardInterrupt` und `SystemExit` sollen weiter propagieren.

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 7</span>
# Exception-Hierarchie erkunden
# </span>
# </div>

# %% [markdown]
# 1. Schreibe eine Funktion `zeige_mro(exception_klasse)`,
#    die die Vererbungskette einer Exception als lesbaren String ausgibt:
#    `'ZeroDivisionError -> ArithmeticError -> Exception -> BaseException -> object'`
# 2. Teste mit: `ZeroDivisionError`, `FileNotFoundError`, `KeyError`, `UnicodeDecodeError`.
# 3. Schreibe eine Funktion `gemeinsamer_vorfahre(e1_klasse, e2_klasse)`,
#    die den naechsten gemeinsamen Vorfahren zweier Exception-Klassen zurueckgibt.
#    Nutze `__mro__`.
# 4. Teste:
# ```python
# print(gemeinsamer_vorfahre(ZeroDivisionError, OverflowError))
# # ArithmeticError
# print(gemeinsamer_vorfahre(ValueError, TypeError))
# # Exception
# print(gemeinsamer_vorfahre(FileNotFoundError, PermissionError))
# # OSError
# ```

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 8</span>
# Exception-Objekt: Daten transportieren
# </span>
# </div>

# %% [markdown]
# 1. Fuehre aus:
# ```python
# try:
#     raise ValueError('Ungueltige HP', -50, 'Bereich: 0-500')
# except ValueError as e:
#     print(e.args)
#     print(e.args[0])   # Meldung
#     print(e.args[1])   # fehlerhafter Wert
#     print(e.args[2])   # Bereichsinfo
# ```
# 2. Schreibe eine Funktion `validiere_held(name, hp, staerke)`, die bei ungueltigem
#    Wert einen `ValueError` mit drei Argumenten wirft:
#    dem Feldnamen, dem ungueltigem Wert und einer Bereichsbeschreibung.
# 3. Fange den Fehler ab und gib alle drei `args`-Werte getrennt aus.
# 4. Erklaere als Kommentar: Wann ist es sinnvoll, mehrere Werte in `args`
#    zu speichern statt alles in einen String zu packen?

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 9</span>
# Exceptions als Event-Klassen
# </span>
# </div>

# %% [markdown]
# 1. Schreibe eine Klasse `SpielEnde(Exception)` mit `pass`.
#    Schreibe eine Klasse `SpielGewonnen(SpielEnde)` mit `pass`.
#    Schreibe eine Klasse `SpielVerloren(SpielEnde)` mit `pass`.
# 2. Schreibe eine Funktion `spiel_schleife(runden)`, die:
#    - `runden` Runden simuliert
#    - Bei Runde 3: `raise SpielGewonnen('Alle Gegner besiegt!')`
#    - Den Fehler nicht selbst behandelt
# 3. Rufe `spiel_schleife(10)` auf und fange `SpielGewonnen` und `SpielVerloren`
#    separat ab, dann `SpielEnde` als Fallback.
# 4. Erklaere als Kommentar: Was meint der PCAP-Syllabus mit dem Begriff
#    'event classes' und wie unterscheidet sich dieser Einsatz von normalem
#    Fehler-Handling?
# 5. Pruefe: Faengt `except SpielEnde` auch `SpielGewonnen` ab? Warum?

# %% [markdown]
# <div style="background:#0b1929;border-left:4px solid #4fc3f7;border-radius:4px;padding:0.75em 1.2em;margin:2rem 0 1.2rem 0;font-family:'Segoe UI',sans-serif;">
# <span style="font-size:clamp(1rem,2.2vw,1.25rem);font-weight:600;color:#e8eaf6;letter-spacing:-0.01em;">
# <span style="font-size:0.65rem;letter-spacing:0.1em;text-transform:uppercase;color:#4fc3f7;background:rgba(79,195,247,0.12);border:1px solid rgba(79,195,247,0.3);border-radius:3px;padding:0.2em 0.55em;margin-right:0.75em;vertical-align:middle;white-space:nowrap;">Aufgabe 10</span>
# Kombination: Fehlerprotokoll
# </span>
# </div>

# %% [markdown]
# Schreibe eine Funktion `verarbeite_batch(eingaben)`, die eine Liste von Strings
# entgegennimmt und jede als Zahl versucht zu verarbeiten.
#
# Anforderungen:
# - Jede Eingabe wird in `int` umgewandelt und quadriert
# - Fehler unterbrechen nicht die gesamte Verarbeitung
# - Die Funktion gibt ein Dictionary zurueck:
#   - `'ergebnisse'`: Liste der erfolgreichen Werte
#   - `'fehler'`: Liste von Tupeln `(eingabe, fehlertyp, meldung)`
# - Nutze `type(e).__name__` fuer den Fehlertyp und `str(e)` fuer die Meldung
#
# Teste:
# ```python
# ergebnis = verarbeite_batch(['4', 'abc', '7', '', '3'])
# print('Ergebnisse:', ergebnis['ergebnisse'])  # [16, 49, 9]
# print('Fehler:', ergebnis['fehler'])          # 2 Fehler
# ```
#
# Dokumentation: https://docs.python.org/3/library/exceptions.html
